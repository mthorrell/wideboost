# %%
import sys
import time
from wideboost.wrappers import wxgb
import numpy as np
import xgboost as xgb

import tensorflow_datasets as tfds
from matplotlib import pyplot as plt

(ds_train, ds_test), ds_info = tfds.load(
    'mnist',
    split=['train', 'test'],
    shuffle_files=False,
    as_supervised=True,
    with_info=True,
)

for i in ds_train.batch(60000):
    a = i
    
for i in ds_test.batch(60000):
    b = i

# %%
xtrain = a[0].numpy().reshape([-1,28*28])
ytrain = a[1].numpy()

xtest = b[0].numpy().reshape([-1,28*28])
ytest = b[1].numpy()

# %%
def _onehot(Y):
    b = np.zeros((Y.shape[0], Y.max().astype(int)+1))
    b[np.arange(Y.shape[0]),Y.astype(int).flatten()] = 1
    return b

# %%
def get_data(seed):
    np.random.seed(seed)
    train_idx = np.random.choice(range(xtrain.shape[0]), round(xtrain.shape[0] * 0.7), replace=False)
    valid_idx = np.array(list(set(range(xtrain.shape[0])) - set(train_idx)))
    train_idx = np.random.choice(train_idx, 3_000, replace=False)
    valid_idx = np.random.choice(valid_idx, 2_000, replace=False)

    test_idx = np.random.choice(range(xtest.shape[0]), 1_000, replace=False)

    features = np.random.choice(range(xtrain.shape[1]), 200, replace=False)


    y_train = _onehot(ytrain[train_idx])
    y_valid = _onehot(ytrain[valid_idx])
    y_test =  _onehot(ytest[test_idx])

    return (
        xtrain[train_idx[:,None], features],
        xtrain[valid_idx[:,None], features],
        xtest[test_idx[:,None], features], y_train, y_valid, y_test
    )

# %%
from hyperopt import fmin, tpe, hp, STATUS_OK, space_eval
import os

iters = 30
results = []
for est in range(iters):

    t0 = time.time()
    x_train, x_valid, x_test, y_train, y_valid, y_test = get_data(1000 + est)
    watchlist = [
        ((x_train, y_train),'train'),
        ((x_test, y_test), 'test'),
        ((x_valid, y_valid), 'valid')
    ]

    best_val = 1000.0
    xgb_test_val = 1000.0
    nrounds = 0
    xgb_param = {}

    def objective(param):
        global best_val
        global xgb_test_val
        global xgb_param
        global nrounds
        num_round = 500
        param['output_dim'] = 10
        param['nthread'] = 2
        print(param)

        xgb_results = {}
        wbst = wxgb.fit(
            x_train, y_train,
            param, num_round, watchlist,
            evals_result=xgb_results,
            early_stopping_rounds=20,
            verbose_eval=200
        )
        
        if (min(xgb_results['valid']['many_logloss'])) < best_val:
            print("NEW BEST VALUE!")
            best_val = min(xgb_results['valid']['many_logloss'])
            xgb_test_val = xgb_results['test']['many_logloss'][
                np.argmin(xgb_results['valid']['many_logloss'])
            ]
            nrounds = np.argmin(xgb_results['valid']['many_logloss']) + 1
            xgb_param = param

        return {'loss': min(xgb_results['valid']['many_logloss']), 'status': STATUS_OK }

    spc = {
        'btype': hp.choice('btype',['I', 'In', 'R', 'Rn']),
        'extra_dims': hp.choice('extra_dims',[0,1,2,3,4,5,6,7]),
        'objective': hp.choice('objective',['manybinary:logistic']),
        'eval_metric':hp.choice('eval_metric',[['many_logloss']]),
        'eta': hp.loguniform('eta', -7, 0),
        'beta_eta': hp.loguniform('beta_eta', -7, 0),
        'max_depth' : hp.choice('max_depth',range(1,11)),
        'subsample': hp.uniform('subsample', 0.5, 1),
        'colsample_bytree': hp.uniform('colsample_bytree', 0.5, 1),
        'colsample_bylevel': hp.uniform('colsample_bylevel', 0.5, 1),
        'min_child_weight': hp.loguniform('min_child_weight', -16, 5),
        'alpha': hp.choice('alpha', [0, hp.loguniform('alpha_positive', -16, 2)]),
        'lambda': hp.choice('lambda', [0, hp.loguniform('lambda_positive', -16, 2)]),
        'gamma': hp.choice('gamma', [0, hp.loguniform('gamma_positive', -16, 2)])
    }
    os.environ['HYPEROPT_FMIN_SEED'] = '101010'
    best = fmin(objective,
        space=spc,
        algo=tpe.suggest,
        max_evals=25)
    t1 = time.time()
    results.append({
        'iter': est,
        'valid_logloss': best_val,
        'test_logloss': xgb_test_val,
        'num_rounds': nrounds,
        'time_diff': t1 - t0,
        'winning_param': xgb_param.copy()
    })
# Out:
# {'alpha': 8.813057946902575e-07, 'beta_eta': 0.0016692834513794938, 'btype': 'R', 'colsample_bylevel': 0.7489980469009814, 'colsample_bytree': 0.9420146676089547, 'eta': 0.0070706936561268224, 'eval_metric': ('many_logloss',), 'extra_dims': 2, 'gamma': 0, 'lambda': 0, 'max_depth': 5, 'min_child_weight': 2.1041667775099838e-05, 'objective': 'manybinary:logistic', 'subsample': 0.6262451727083667, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.65380	test-many_logloss:0.65374	valid-many_logloss:0.65379
# [200]	train-many_logloss:0.10360	test-many_logloss:0.12882	valid-many_logloss:0.12791
# [400]	train-many_logloss:0.03629	test-many_logloss:0.07274	valid-many_logloss:0.07304
# [499]	train-many_logloss:0.02289	test-many_logloss:0.06268	valid-many_logloss:0.06328
# NEW BEST VALUE!
# {'alpha': 0, 'beta_eta': 0.07375799600401638, 'btype': 'I', 'colsample_bylevel': 0.8357246683355697, 'colsample_bytree': 0.7491187395188089, 'eta': 0.605518780660455, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0, 'lambda': 0, 'max_depth': 5, 'min_child_weight': 118.844312919608, 'objective': 'manybinary:logistic', 'subsample': 0.6525233714163394, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.39941	test-many_logloss:0.39904	valid-many_logloss:0.40006
# [111]	train-many_logloss:nan	test-many_logloss:nan	valid-many_logloss:nan
#   8%|▊         | 2/25 [02:10<21:34, 56.28s/trial, best loss: 0.063283]
# ../wideboost/wideboost/evals/classification.py:82: RuntimeWarning: divide by zero encountered in log
#   return -np.mean(np.log(p))
#
# ../wideboost/wideboost/evals/classification.py:80: RuntimeWarning: overflow encountered in exp
#   p = 1/(1 + np.exp(-logits))
#
# ../wideboost/wideboost/evals/classification.py:82: RuntimeWarning: invalid value encountered in log
#   return -np.mean(np.log(p))
# {'alpha': 0, 'beta_eta': 0.012588600896345226, 'btype': 'Rn', 'colsample_bylevel': 0.5547269545129563, 'colsample_bytree': 0.9843635186756493, 'eta': 0.5949933323999959, 'eval_metric': ('many_logloss',), 'extra_dims': 4, 'gamma': 0.00013347887526644314, 'lambda': 0, 'max_depth': 9, 'min_child_weight': 7.283920920982167e-06, 'objective': 'manybinary:logistic', 'subsample': 0.9927469091208938, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.94147	test-many_logloss:0.97079	valid-many_logloss:0.96448
#   8%|▊         | 2/25 [02:10<21:34, 56.28s/trial, best loss: 0.063283]
# ../wideboost/wideboost/objectives/manybinarylogloss.py:14: RuntimeWarning: overflow encountered in exp
#   P = 1 / (1 + np.exp(-logits))
# [19]	train-many_logloss:inf	test-many_logloss:inf	valid-many_logloss:inf
# {'alpha': 1.0366863221923632, 'beta_eta': 0.13640103803528691, 'btype': 'Rn', 'colsample_bylevel': 0.6367989155272455, 'colsample_bytree': 0.6974194337846622, 'eta': 0.3029677824305006, 'eval_metric': ('many_logloss',), 'extra_dims': 6, 'gamma': 1.5812851156161036, 'lambda': 1.2783614674881826e-06, 'max_depth': 5, 'min_child_weight': 2.558034001077105, 'objective': 'manybinary:logistic', 'subsample': 0.7481581307597385, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.55526	test-many_logloss:0.55322	valid-many_logloss:0.55533
# [20]	train-many_logloss:nan	test-many_logloss:nan	valid-many_logloss:nan
# {'alpha': 0.0015268888255807838, 'beta_eta': 0.20179405533498707, 'btype': 'R', 'colsample_bylevel': 0.822829897275416, 'colsample_bytree': 0.8661025998484644, 'eta': 0.011434936316016709, 'eval_metric': ('many_logloss',), 'extra_dims': 1, 'gamma': 0, 'lambda': 2.091554134375915, 'max_depth': 8, 'min_child_weight': 1.6723514459697203e-05, 'objective': 'manybinary:logistic', 'subsample': 0.6325684178842439, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.63274	test-many_logloss:0.63259	valid-many_logloss:0.63272
# [19]	train-many_logloss:inf	test-many_logloss:inf	valid-many_logloss:inf
# {'alpha': 7.049352314660277e-05, 'beta_eta': 0.12137127268126893, 'btype': 'Rn', 'colsample_bylevel': 0.9439090074967231, 'colsample_bytree': 0.5525925639927433, 'eta': 0.0009915520889927426, 'eval_metric': ('many_logloss',), 'extra_dims': 3, 'gamma': 0, 'lambda': 0.004073992634408555, 'max_depth': 2, 'min_child_weight': 1.3633143522854873e-06, 'objective': 'manybinary:logistic', 'subsample': 0.9311207654760087, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.68681	test-many_logloss:0.68682	valid-many_logloss:0.68681
# [60]	train-many_logloss:0.16541	test-many_logloss:0.17529	valid-many_logloss:0.17794
# {'alpha': 8.581958439353927e-05, 'beta_eta': 0.4437471588909133, 'btype': 'R', 'colsample_bylevel': 0.787125082065971, 'colsample_bytree': 0.5243474561426513, 'eta': 0.8099003407203538, 'eval_metric': ('many_logloss',), 'extra_dims': 3, 'gamma': 7.475715249737038e-05, 'lambda': 0.0003639646509775927, 'max_depth': 7, 'min_child_weight': 0.09759627970810976, 'objective': 'manybinary:logistic', 'subsample': 0.553442319017114, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:1.19573	test-many_logloss:1.21086	valid-many_logloss:1.20588
# [20]	train-many_logloss:inf	test-many_logloss:inf	valid-many_logloss:inf
# {'alpha': 0, 'beta_eta': 0.1292065517955496, 'btype': 'Rn', 'colsample_bylevel': 0.7061150549075759, 'colsample_bytree': 0.5843009197915733, 'eta': 0.002630107568123181, 'eval_metric': ('many_logloss',), 'extra_dims': 2, 'gamma': 6.947115616562489, 'lambda': 0, 'max_depth': 10, 'min_child_weight': 41.36978142254861, 'objective': 'manybinary:logistic', 'subsample': 0.7453409993563878, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.67781	test-many_logloss:0.67779	valid-many_logloss:0.67780
# [71]	train-many_logloss:0.10274	test-many_logloss:0.14051	valid-many_logloss:0.14343
# {'alpha': 0, 'beta_eta': 0.11363289588177274, 'btype': 'Rn', 'colsample_bylevel': 0.8017715093779021, 'colsample_bytree': 0.7625111741024486, 'eta': 0.007606220882567551, 'eval_metric': ('many_logloss',), 'extra_dims': 4, 'gamma': 0.001053204847233351, 'lambda': 0.23316250775856961, 'max_depth': 1, 'min_child_weight': 1.9088058756735313e-07, 'objective': 'manybinary:logistic', 'subsample': 0.5239057927863935, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.64524	test-many_logloss:0.64531	valid-many_logloss:0.64529
# [71]	train-many_logloss:0.17529	test-many_logloss:0.18069	valid-many_logloss:0.17679
# {'alpha': 0, 'beta_eta': 0.2023070079269739, 'btype': 'I', 'colsample_bylevel': 0.98982155285091, 'colsample_bytree': 0.8137063678634311, 'eta': 0.021437825449384364, 'eval_metric': ('many_logloss',), 'extra_dims': 2, 'gamma': 0, 'lambda': 0, 'max_depth': 5, 'min_child_weight': 2.5600171535202e-07, 'objective': 'manybinary:logistic', 'subsample': 0.7174114308249333, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.65645	test-many_logloss:0.65707	valid-many_logloss:0.65695
# [40]	train-many_logloss:0.02288	test-many_logloss:0.14398	valid-many_logloss:0.13955
# {'alpha': 0, 'beta_eta': 0.675621539900281, 'btype': 'I', 'colsample_bylevel': 0.6189065258301154, 'colsample_bytree': 0.7882001782331782, 'eta': 0.003770077706590942, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0.0006381725365621713, 'lambda': 0, 'max_depth': 1, 'min_child_weight': 0.05537987461653371, 'objective': 'manybinary:logistic', 'subsample': 0.6537419349296045, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.69057	test-many_logloss:0.69059	valid-many_logloss:0.69058
# [24]	train-many_logloss:inf	test-many_logloss:inf	valid-many_logloss:inf
# {'alpha': 0, 'beta_eta': 0.06489049340354942, 'btype': 'I', 'colsample_bylevel': 0.8729133438901646, 'colsample_bytree': 0.5205123603280772, 'eta': 0.0309650866085196, 'eval_metric': ('many_logloss',), 'extra_dims': 5, 'gamma': 0, 'lambda': 7.910525070154376e-06, 'max_depth': 3, 'min_child_weight': 7.405155036744976e-05, 'objective': 'manybinary:logistic', 'subsample': 0.6231629412057431, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.60330	test-many_logloss:0.60353	valid-many_logloss:0.60341
# [102]	train-many_logloss:0.02217	test-many_logloss:0.08079	valid-many_logloss:0.08023
# {'alpha': 0.014845224338582359, 'beta_eta': 0.03770137496335071, 'btype': 'Rn', 'colsample_bylevel': 0.7211698432094364, 'colsample_bytree': 0.712394975511369, 'eta': 0.008477424619483462, 'eval_metric': ('many_logloss',), 'extra_dims': 1, 'gamma': 0, 'lambda': 0, 'max_depth': 3, 'min_child_weight': 32.756265617720345, 'objective': 'manybinary:logistic', 'subsample': 0.6995489417449295, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.65006	test-many_logloss:0.65000	valid-many_logloss:0.65009
# [200]	train-many_logloss:0.06521	test-many_logloss:0.09939	valid-many_logloss:0.09960
# [227]	train-many_logloss:0.05933	test-many_logloss:0.09944	valid-many_logloss:0.09946
# {'alpha': 2.7324514268482383, 'beta_eta': 0.08036958137175818, 'btype': 'R', 'colsample_bylevel': 0.7987531851832483, 'colsample_bytree': 0.7299740823920091, 'eta': 0.06030778497723384, 'eval_metric': ('many_logloss',), 'extra_dims': 3, 'gamma': 0, 'lambda': 0, 'max_depth': 8, 'min_child_weight': 0.00023882505207060682, 'objective': 'manybinary:logistic', 'subsample': 0.8750385697829414, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.42510	test-many_logloss:0.42566	valid-many_logloss:0.42559
# [20]	train-many_logloss:inf	test-many_logloss:inf	valid-many_logloss:inf
# {'alpha': 0, 'beta_eta': 0.009060610135766442, 'btype': 'I', 'colsample_bylevel': 0.7332732947918047, 'colsample_bytree': 0.5030735772414907, 'eta': 0.0015245875835189877, 'eval_metric': ('many_logloss',), 'extra_dims': 7, 'gamma': 9.066632495478617e-06, 'lambda': 0, 'max_depth': 3, 'min_child_weight': 135.18110003620356, 'objective': 'manybinary:logistic', 'subsample': 0.5593100367488764, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.68659	test-many_logloss:0.68659	valid-many_logloss:0.68659
# [200]	train-many_logloss:0.16757	test-many_logloss:0.17432	valid-many_logloss:0.17369
# [400]	train-many_logloss:0.09170	test-many_logloss:0.10524	valid-many_logloss:0.10467
# [499]	train-many_logloss:0.07734	test-many_logloss:0.09541	valid-many_logloss:0.09492
# {'alpha': 9.442657203270879e-05, 'beta_eta': 0.17396370377116593, 'btype': 'I', 'colsample_bylevel': 0.7781226592895327, 'colsample_bytree': 0.6398164878102375, 'eta': 0.0041851001124752684, 'eval_metric': ('many_logloss',), 'extra_dims': 7, 'gamma': 5.825640644469816e-06, 'lambda': 0, 'max_depth': 8, 'min_child_weight': 0.00537473915613328, 'objective': 'manybinary:logistic', 'subsample': 0.5391816076002862, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.67517	test-many_logloss:0.67545	valid-many_logloss:0.67544
# [44]	train-many_logloss:0.01651	test-many_logloss:0.12778	valid-many_logloss:0.12868
# {'alpha': 0, 'beta_eta': 0.7112779064038146, 'btype': 'I', 'colsample_bylevel': 0.980487461508577, 'colsample_bytree': 0.872601457169579, 'eta': 0.46040749038190176, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0, 'lambda': 0, 'max_depth': 5, 'min_child_weight': 0.0003681699610575285, 'objective': 'manybinary:logistic', 'subsample': 0.7369430758094139, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.38356	test-many_logloss:0.39847	valid-many_logloss:0.39799
# [21]	train-many_logloss:inf	test-many_logloss:inf	valid-many_logloss:inf
# {'alpha': 0, 'beta_eta': 0.004046103790871514, 'btype': 'I', 'colsample_bylevel': 0.7818800515438491, 'colsample_bytree': 0.7724637498474807, 'eta': 0.008563159803242014, 'eval_metric': ('many_logloss',), 'extra_dims': 4, 'gamma': 1.138875246733091, 'lambda': 0.004929740945608459, 'max_depth': 8, 'min_child_weight': 1.2189098145853323e-06, 'objective': 'manybinary:logistic', 'subsample': 0.92406704328224, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.66861	test-many_logloss:0.66929	valid-many_logloss:0.66929
# [200]	train-many_logloss:0.02989	test-many_logloss:0.08598	valid-many_logloss:0.08441
# [400]	train-many_logloss:0.00846	test-many_logloss:0.06844	valid-many_logloss:0.06731
# [498]	train-many_logloss:0.00602	test-many_logloss:0.06796	valid-many_logloss:0.06689
# {'alpha': 0, 'beta_eta': 0.008940815077581921, 'btype': 'R', 'colsample_bylevel': 0.947651214492775, 'colsample_bytree': 0.8633457836387857, 'eta': 0.3977029463511548, 'eval_metric': ('many_logloss',), 'extra_dims': 7, 'gamma': 0.003128466805888169, 'lambda': 0, 'max_depth': 6, 'min_child_weight': 23.81766245704533, 'objective': 'manybinary:logistic', 'subsample': 0.8289219023831419, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.79814	test-many_logloss:0.80222	valid-many_logloss:0.79844
# [19]	train-many_logloss:nan	test-many_logloss:nan	valid-many_logloss:nan
# {'alpha': 0, 'beta_eta': 0.7189262806817021, 'btype': 'Rn', 'colsample_bylevel': 0.8025654416649992, 'colsample_bytree': 0.8748052006921443, 'eta': 0.009393489875683971, 'eval_metric': ('many_logloss',), 'extra_dims': 3, 'gamma': 0, 'lambda': 0, 'max_depth': 2, 'min_child_weight': 0.013234942416650719, 'objective': 'manybinary:logistic', 'subsample': 0.8694541664166509, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.63387	test-many_logloss:0.63408	valid-many_logloss:0.63403
# [25]	train-many_logloss:nan	test-many_logloss:nan	valid-many_logloss:nan
# {'alpha': 2.5240365004235283e-07, 'beta_eta': 0.0012215190837876378, 'btype': 'In', 'colsample_bylevel': 0.8788092996859548, 'colsample_bytree': 0.9767086318631194, 'eta': 0.14876123484960702, 'eval_metric': ('many_logloss',), 'extra_dims': 4, 'gamma': 0.055243004681850574, 'lambda': 0.008679746735189764, 'max_depth': 4, 'min_child_weight': 1.7599154275713062e-06, 'objective': 'manybinary:logistic', 'subsample': 0.8017393719767765, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.38042	test-many_logloss:0.38290	valid-many_logloss:0.38362
# [116]	train-many_logloss:0.00187	test-many_logloss:0.06279	valid-many_logloss:0.06078
# NEW BEST VALUE!
# {'alpha': 1.3010046524364964e-07, 'beta_eta': 0.0009424848537938038, 'btype': 'In', 'colsample_bylevel': 0.8884275174529376, 'colsample_bytree': 0.9893656719086061, 'eta': 0.13615993293609235, 'eval_metric': ('many_logloss',), 'extra_dims': 2, 'gamma': 0, 'lambda': 4.7840334774841065, 'max_depth': 4, 'min_child_weight': 0.0008214702178563566, 'objective': 'manybinary:logistic', 'subsample': 0.798954703236525, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.50232	test-many_logloss:0.50330	valid-many_logloss:0.50338
# [20]	train-many_logloss:inf	test-many_logloss:inf	valid-many_logloss:inf
# {'alpha': 1.4231210544165036e-07, 'beta_eta': 0.0016286758586114463, 'btype': 'In', 'colsample_bylevel': 0.6571011266101066, 'colsample_bytree': 0.9335794179393762, 'eta': 0.1363073561710967, 'eval_metric': ('many_logloss',), 'extra_dims': 6, 'gamma': 0.04780935894057256, 'lambda': 1.5080011767044455e-07, 'max_depth': 4, 'min_child_weight': 3.698366596197951e-05, 'objective': 'manybinary:logistic', 'subsample': 0.8034468582708, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.35182	test-many_logloss:0.35476	valid-many_logloss:0.35471
# [95]	train-many_logloss:0.00279	test-many_logloss:0.06138	valid-many_logloss:0.06111
# {'alpha': 1.0273961037698835e-06, 'beta_eta': 0.0009204375805458518, 'btype': 'In', 'colsample_bylevel': 0.5175131514565298, 'colsample_bytree': 0.9444529427963501, 'eta': 0.18631958047459551, 'eval_metric': ('many_logloss',), 'extra_dims': 6, 'gamma': 0.04723489932495001, 'lambda': 0.00027295123111598373, 'max_depth': 4, 'min_child_weight': 1.5586492835000325e-06, 'objective': 'manybinary:logistic', 'subsample': 0.8022337178539891, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.30560	test-many_logloss:0.30875	valid-many_logloss:0.30842
# [77]	train-many_logloss:0.00255	test-many_logloss:0.05999	valid-many_logloss:0.06111
# {'alpha': 2.559875417296009e-06, 'beta_eta': 0.0009188324087939346, 'btype': 'In', 'colsample_bylevel': 0.5240462501592672, 'colsample_bytree': 0.9278800383772242, 'eta': 0.18157952819863127, 'eval_metric': ('many_logloss',), 'extra_dims': 6, 'gamma': 0.06237444623105024, 'lambda': 0.0001600304605879969, 'max_depth': 4, 'min_child_weight': 2.2991729020239517e-06, 'objective': 'manybinary:logistic', 'subsample': 0.7896507746328678, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.31363	test-many_logloss:0.31723	valid-many_logloss:0.31709
# [80]	train-many_logloss:0.00225	test-many_logloss:0.06219	valid-many_logloss:0.06234
# 100%|██████████| 25/25 [11:27<00:00, 27.52s/trial, best loss: 0.060154]
# {'alpha': 8.813057946902575e-07, 'beta_eta': 0.0016692834513794938, 'btype': 'R', 'colsample_bylevel': 0.7489980469009814, 'colsample_bytree': 0.9420146676089547, 'eta': 0.0070706936561268224, 'eval_metric': ('many_logloss',), 'extra_dims': 2, 'gamma': 0, 'lambda': 0, 'max_depth': 5, 'min_child_weight': 2.1041667775099838e-05, 'objective': 'manybinary:logistic', 'subsample': 0.6262451727083667, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.65201	test-many_logloss:0.65200	valid-many_logloss:0.65194
# [200]	train-many_logloss:0.09861	test-many_logloss:0.12336	valid-many_logloss:0.12598
# [400]	train-many_logloss:0.03134	test-many_logloss:0.06617	valid-many_logloss:0.07106
# [499]	train-many_logloss:0.01878	test-many_logloss:0.05625	valid-many_logloss:0.06191
# NEW BEST VALUE!
# {'alpha': 0, 'beta_eta': 0.07375799600401638, 'btype': 'I', 'colsample_bylevel': 0.8357246683355697, 'colsample_bytree': 0.7491187395188089, 'eta': 0.605518780660455, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0, 'lambda': 0, 'max_depth': 5, 'min_child_weight': 118.844312919608, 'objective': 'manybinary:logistic', 'subsample': 0.6525233714163394, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.39971	test-many_logloss:0.40128	valid-many_logloss:0.40161
# [118]	train-many_logloss:0.05801	test-many_logloss:0.11169	valid-many_logloss:0.12696
# {'alpha': 0, 'beta_eta': 0.012588600896345226, 'btype': 'Rn', 'colsample_bylevel': 0.5547269545129563, 'colsample_bytree': 0.9843635186756493, 'eta': 0.5949933323999959, 'eval_metric': ('many_logloss',), 'extra_dims': 4, 'gamma': 0.00013347887526644314, 'lambda': 0, 'max_depth': 9, 'min_child_weight': 7.283920920982167e-06, 'objective': 'manybinary:logistic', 'subsample': 0.9927469091208938, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.89223	test-many_logloss:0.91212	valid-many_logloss:0.91357
# [19]	train-many_logloss:inf	test-many_logloss:inf	valid-many_logloss:inf
# {'alpha': 1.0366863221923632, 'beta_eta': 0.13640103803528691, 'btype': 'Rn', 'colsample_bylevel': 0.6367989155272455, 'colsample_bytree': 0.6974194337846622, 'eta': 0.3029677824305006, 'eval_metric': ('many_logloss',), 'extra_dims': 6, 'gamma': 1.5812851156161036, 'lambda': 1.2783614674881826e-06, 'max_depth': 5, 'min_child_weight': 2.558034001077105, 'objective': 'manybinary:logistic', 'subsample': 0.7481581307597385, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.57971	test-many_logloss:0.58119	valid-many_logloss:0.58067
# [20]	train-many_logloss:inf	test-many_logloss:inf	valid-many_logloss:inf
# {'alpha': 0.0015268888255807838, 'beta_eta': 0.20179405533498707, 'btype': 'R', 'colsample_bylevel': 0.822829897275416, 'colsample_bytree': 0.8661025998484644, 'eta': 0.011434936316016709, 'eval_metric': ('many_logloss',), 'extra_dims': 1, 'gamma': 0, 'lambda': 2.091554134375915, 'max_depth': 8, 'min_child_weight': 1.6723514459697203e-05, 'objective': 'manybinary:logistic', 'subsample': 0.6325684178842439, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.63633	test-many_logloss:0.63629	valid-many_logloss:0.63626
# [52]	train-many_logloss:0.01783	test-many_logloss:0.10965	valid-many_logloss:0.12495
# {'alpha': 7.049352314660277e-05, 'beta_eta': 0.12137127268126893, 'btype': 'Rn', 'colsample_bylevel': 0.9439090074967231, 'colsample_bytree': 0.5525925639927433, 'eta': 0.0009915520889927426, 'eval_metric': ('many_logloss',), 'extra_dims': 3, 'gamma': 0, 'lambda': 0.004073992634408555, 'max_depth': 2, 'min_child_weight': 1.3633143522854873e-06, 'objective': 'manybinary:logistic', 'subsample': 0.9311207654760087, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.68735	test-many_logloss:0.68734	valid-many_logloss:0.68734
# [61]	train-many_logloss:0.16321	test-many_logloss:0.17985	valid-many_logloss:0.17341
# {'alpha': 8.581958439353927e-05, 'beta_eta': 0.4437471588909133, 'btype': 'R', 'colsample_bylevel': 0.787125082065971, 'colsample_bytree': 0.5243474561426513, 'eta': 0.8099003407203538, 'eval_metric': ('many_logloss',), 'extra_dims': 3, 'gamma': 7.475715249737038e-05, 'lambda': 0.0003639646509775927, 'max_depth': 7, 'min_child_weight': 0.09759627970810976, 'objective': 'manybinary:logistic', 'subsample': 0.553442319017114, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:1.22509	test-many_logloss:1.23733	valid-many_logloss:1.24090
# [19]	train-many_logloss:inf	test-many_logloss:inf	valid-many_logloss:inf
# {'alpha': 0, 'beta_eta': 0.1292065517955496, 'btype': 'Rn', 'colsample_bylevel': 0.7061150549075759, 'colsample_bytree': 0.5843009197915733, 'eta': 0.002630107568123181, 'eval_metric': ('many_logloss',), 'extra_dims': 2, 'gamma': 6.947115616562489, 'lambda': 0, 'max_depth': 10, 'min_child_weight': 41.36978142254861, 'objective': 'manybinary:logistic', 'subsample': 0.7453409993563878, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.67772	test-many_logloss:0.67773	valid-many_logloss:0.67773
# [70]	train-many_logloss:0.09520	test-many_logloss:0.14374	valid-many_logloss:0.14561
# {'alpha': 0, 'beta_eta': 0.11363289588177274, 'btype': 'Rn', 'colsample_bylevel': 0.8017715093779021, 'colsample_bytree': 0.7625111741024486, 'eta': 0.007606220882567551, 'eval_metric': ('many_logloss',), 'extra_dims': 4, 'gamma': 0.001053204847233351, 'lambda': 0.23316250775856961, 'max_depth': 1, 'min_child_weight': 1.9088058756735313e-07, 'objective': 'manybinary:logistic', 'subsample': 0.5239057927863935, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.64250	test-many_logloss:0.64251	valid-many_logloss:0.64240
# [70]	train-many_logloss:0.15908	test-many_logloss:0.16094	valid-many_logloss:0.16985
# {'alpha': 0, 'beta_eta': 0.2023070079269739, 'btype': 'I', 'colsample_bylevel': 0.98982155285091, 'colsample_bytree': 0.8137063678634311, 'eta': 0.021437825449384364, 'eval_metric': ('many_logloss',), 'extra_dims': 2, 'gamma': 0, 'lambda': 0, 'max_depth': 5, 'min_child_weight': 2.5600171535202e-07, 'objective': 'manybinary:logistic', 'subsample': 0.7174114308249333, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.65399	test-many_logloss:0.65452	valid-many_logloss:0.65469
# [39]	train-many_logloss:0.01849	test-many_logloss:0.12482	valid-many_logloss:0.13975
# {'alpha': 0, 'beta_eta': 0.675621539900281, 'btype': 'I', 'colsample_bylevel': 0.6189065258301154, 'colsample_bytree': 0.7882001782331782, 'eta': 0.003770077706590942, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0.0006381725365621713, 'lambda': 0, 'max_depth': 1, 'min_child_weight': 0.05537987461653371, 'objective': 'manybinary:logistic', 'subsample': 0.6537419349296045, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.69059	test-many_logloss:0.69061	valid-many_logloss:0.69061
# [24]	train-many_logloss:0.22280	test-many_logloss:0.22908	valid-many_logloss:0.23393
# {'alpha': 0, 'beta_eta': 0.06489049340354942, 'btype': 'I', 'colsample_bylevel': 0.8729133438901646, 'colsample_bytree': 0.5205123603280772, 'eta': 0.0309650866085196, 'eval_metric': ('many_logloss',), 'extra_dims': 5, 'gamma': 0, 'lambda': 7.910525070154376e-06, 'max_depth': 3, 'min_child_weight': 7.405155036744976e-05, 'objective': 'manybinary:logistic', 'subsample': 0.6231629412057431, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.60129	test-many_logloss:0.60177	valid-many_logloss:0.60190
# [98]	train-many_logloss:0.01685	test-many_logloss:0.07698	valid-many_logloss:0.08620
# {'alpha': 0.014845224338582359, 'beta_eta': 0.03770137496335071, 'btype': 'Rn', 'colsample_bylevel': 0.7211698432094364, 'colsample_bytree': 0.712394975511369, 'eta': 0.008477424619483462, 'eval_metric': ('many_logloss',), 'extra_dims': 1, 'gamma': 0, 'lambda': 0, 'max_depth': 3, 'min_child_weight': 32.756265617720345, 'objective': 'manybinary:logistic', 'subsample': 0.6995489417449295, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.64899	test-many_logloss:0.64907	valid-many_logloss:0.64898
# [188]	train-many_logloss:0.05287	test-many_logloss:0.09097	valid-many_logloss:0.09763
# {'alpha': 2.7324514268482383, 'beta_eta': 0.08036958137175818, 'btype': 'R', 'colsample_bylevel': 0.7987531851832483, 'colsample_bytree': 0.7299740823920091, 'eta': 0.06030778497723384, 'eval_metric': ('many_logloss',), 'extra_dims': 3, 'gamma': 0, 'lambda': 0, 'max_depth': 8, 'min_child_weight': 0.00023882505207060682, 'objective': 'manybinary:logistic', 'subsample': 0.8750385697829414, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.42036	test-many_logloss:0.42068	valid-many_logloss:0.42033
# [19]	train-many_logloss:inf	test-many_logloss:inf	valid-many_logloss:inf
# {'alpha': 0, 'beta_eta': 0.009060610135766442, 'btype': 'I', 'colsample_bylevel': 0.7332732947918047, 'colsample_bytree': 0.5030735772414907, 'eta': 0.0015245875835189877, 'eval_metric': ('many_logloss',), 'extra_dims': 7, 'gamma': 9.066632495478617e-06, 'lambda': 0, 'max_depth': 3, 'min_child_weight': 135.18110003620356, 'objective': 'manybinary:logistic', 'subsample': 0.5593100367488764, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.68656	test-many_logloss:0.68658	valid-many_logloss:0.68658
# [200]	train-many_logloss:0.16314	test-many_logloss:0.17268	valid-many_logloss:0.17526
# [400]	train-many_logloss:0.08412	test-many_logloss:0.10028	valid-many_logloss:0.10491
# [499]	train-many_logloss:0.06888	test-many_logloss:0.08938	valid-many_logloss:0.09472
# {'alpha': 9.442657203270879e-05, 'beta_eta': 0.17396370377116593, 'btype': 'I', 'colsample_bylevel': 0.7781226592895327, 'colsample_bytree': 0.6398164878102375, 'eta': 0.0041851001124752684, 'eval_metric': ('many_logloss',), 'extra_dims': 7, 'gamma': 5.825640644469816e-06, 'lambda': 0, 'max_depth': 8, 'min_child_weight': 0.00537473915613328, 'objective': 'manybinary:logistic', 'subsample': 0.5391816076002862, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.67519	test-many_logloss:0.67546	valid-many_logloss:0.67547
# [44]	train-many_logloss:0.01395	test-many_logloss:0.11459	valid-many_logloss:0.12440
# {'alpha': 0, 'beta_eta': 0.7112779064038146, 'btype': 'I', 'colsample_bylevel': 0.980487461508577, 'colsample_bytree': 0.872601457169579, 'eta': 0.46040749038190176, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0, 'lambda': 0, 'max_depth': 5, 'min_child_weight': 0.0003681699610575285, 'objective': 'manybinary:logistic', 'subsample': 0.7369430758094139, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.38366	test-many_logloss:0.39730	valid-many_logloss:0.39855
# [21]	train-many_logloss:nan	test-many_logloss:nan	valid-many_logloss:nan
# {'alpha': 0, 'beta_eta': 0.004046103790871514, 'btype': 'I', 'colsample_bylevel': 0.7818800515438491, 'colsample_bytree': 0.7724637498474807, 'eta': 0.008563159803242014, 'eval_metric': ('many_logloss',), 'extra_dims': 4, 'gamma': 1.138875246733091, 'lambda': 0.004929740945608459, 'max_depth': 8, 'min_child_weight': 1.2189098145853323e-06, 'objective': 'manybinary:logistic', 'subsample': 0.92406704328224, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.66866	test-many_logloss:0.66931	valid-many_logloss:0.66940
# [200]	train-many_logloss:0.02813	test-many_logloss:0.07985	valid-many_logloss:0.08543
# [400]	train-many_logloss:0.00753	test-many_logloss:0.06121	valid-many_logloss:0.06966
# [469]	train-many_logloss:0.00580	test-many_logloss:0.06051	valid-many_logloss:0.06952
# {'alpha': 0, 'beta_eta': 0.008940815077581921, 'btype': 'R', 'colsample_bylevel': 0.947651214492775, 'colsample_bytree': 0.8633457836387857, 'eta': 0.3977029463511548, 'eval_metric': ('many_logloss',), 'extra_dims': 7, 'gamma': 0.003128466805888169, 'lambda': 0, 'max_depth': 6, 'min_child_weight': 23.81766245704533, 'objective': 'manybinary:logistic', 'subsample': 0.8289219023831419, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.78526	test-many_logloss:0.79068	valid-many_logloss:0.79058
# [19]	train-many_logloss:nan	test-many_logloss:nan	valid-many_logloss:nan
# {'alpha': 0, 'beta_eta': 0.7189262806817021, 'btype': 'Rn', 'colsample_bylevel': 0.8025654416649992, 'colsample_bytree': 0.8748052006921443, 'eta': 0.009393489875683971, 'eval_metric': ('many_logloss',), 'extra_dims': 3, 'gamma': 0, 'lambda': 0, 'max_depth': 2, 'min_child_weight': 0.013234942416650719, 'objective': 'manybinary:logistic', 'subsample': 0.8694541664166509, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.63760	test-many_logloss:0.63758	valid-many_logloss:0.63757
# [25]	train-many_logloss:nan	test-many_logloss:nan	valid-many_logloss:nan
# {'alpha': 2.5240365004235283e-07, 'beta_eta': 0.0012215190837876378, 'btype': 'In', 'colsample_bylevel': 0.8788092996859548, 'colsample_bytree': 0.9767086318631194, 'eta': 0.14876123484960702, 'eval_metric': ('many_logloss',), 'extra_dims': 4, 'gamma': 0.055243004681850574, 'lambda': 0.008679746735189764, 'max_depth': 4, 'min_child_weight': 1.7599154275713062e-06, 'objective': 'manybinary:logistic', 'subsample': 0.8017393719767765, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.38588	test-many_logloss:0.38932	valid-many_logloss:0.38944
# [97]	train-many_logloss:0.00153	test-many_logloss:0.05157	valid-many_logloss:0.06402
# {'alpha': 1.3010046524364964e-07, 'beta_eta': 0.0009424848537938038, 'btype': 'In', 'colsample_bylevel': 0.8884275174529376, 'colsample_bytree': 0.9893656719086061, 'eta': 0.13615993293609235, 'eval_metric': ('many_logloss',), 'extra_dims': 2, 'gamma': 0, 'lambda': 4.7840334774841065, 'max_depth': 4, 'min_child_weight': 0.0008214702178563566, 'objective': 'manybinary:logistic', 'subsample': 0.798954703236525, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.49761	test-many_logloss:0.49901	valid-many_logloss:0.49906
# [20]	train-many_logloss:inf	test-many_logloss:inf	valid-many_logloss:inf
# {'alpha': 1.4231210544165036e-07, 'beta_eta': 0.0016286758586114463, 'btype': 'In', 'colsample_bylevel': 0.6571011266101066, 'colsample_bytree': 0.9335794179393762, 'eta': 0.1363073561710967, 'eval_metric': ('many_logloss',), 'extra_dims': 6, 'gamma': 0.04780935894057256, 'lambda': 1.5080011767044455e-07, 'max_depth': 4, 'min_child_weight': 3.698366596197951e-05, 'objective': 'manybinary:logistic', 'subsample': 0.8034468582708, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.34604	test-many_logloss:0.34834	valid-many_logloss:0.34853
# [88]	train-many_logloss:0.00212	test-many_logloss:0.05420	valid-many_logloss:0.06291
# NEW BEST VALUE!
# {'alpha': 1.4664754681880375e-06, 'beta_eta': 0.002000002635921915, 'btype': 'In', 'colsample_bylevel': 0.6603963754053725, 'colsample_bytree': 0.9265334879663432, 'eta': 0.07115224376188432, 'eval_metric': ('many_logloss',), 'extra_dims': 6, 'gamma': 0, 'lambda': 1.2098069395080887e-07, 'max_depth': 4, 'min_child_weight': 4.486306030624562e-05, 'objective': 'manybinary:logistic', 'subsample': 0.6755268295322712, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.47208	test-many_logloss:0.47358	valid-many_logloss:0.47397
# [147]	train-many_logloss:0.00268	test-many_logloss:0.05196	valid-many_logloss:0.06221
# NEW BEST VALUE!
# {'alpha': 2.559875417296009e-06, 'beta_eta': 0.0032775937398758018, 'btype': 'In', 'colsample_bylevel': 0.502178458314058, 'colsample_bytree': 0.9386828416019393, 'eta': 0.09830479795145422, 'eval_metric': ('many_logloss',), 'extra_dims': 6, 'gamma': 1.5061357347532555e-07, 'lambda': 1.8318862008782433e-07, 'max_depth': 4, 'min_child_weight': 0.0015754854783202707, 'objective': 'manybinary:logistic', 'subsample': 0.6878048640107575, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.41883	test-many_logloss:0.42067	valid-many_logloss:0.42106
# [106]	train-many_logloss:0.00290	test-many_logloss:0.05056	valid-many_logloss:0.06406
# 100%|██████████| 25/25 [12:42<00:00, 30.50s/trial, best loss: 0.061296]
# {'alpha': 8.813057946902575e-07, 'beta_eta': 0.0016692834513794938, 'btype': 'R', 'colsample_bylevel': 0.7489980469009814, 'colsample_bytree': 0.9420146676089547, 'eta': 0.0070706936561268224, 'eval_metric': ('many_logloss',), 'extra_dims': 2, 'gamma': 0, 'lambda': 0, 'max_depth': 5, 'min_child_weight': 2.1041667775099838e-05, 'objective': 'manybinary:logistic', 'subsample': 0.6262451727083667, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.65167	test-many_logloss:0.65176	valid-many_logloss:0.65172
# [200]	train-many_logloss:0.09950	test-many_logloss:0.12566	valid-many_logloss:0.12704
# [400]	train-many_logloss:0.03183	test-many_logloss:0.06913	valid-many_logloss:0.07025
# [499]	train-many_logloss:0.01901	test-many_logloss:0.05941	valid-many_logloss:0.06026
# NEW BEST VALUE!
# {'alpha': 0, 'beta_eta': 0.07375799600401638, 'btype': 'I', 'colsample_bylevel': 0.8357246683355697, 'colsample_bytree': 0.7491187395188089, 'eta': 0.605518780660455, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0, 'lambda': 0, 'max_depth': 5, 'min_child_weight': 118.844312919608, 'objective': 'manybinary:logistic', 'subsample': 0.6525233714163394, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.39963	test-many_logloss:0.39968	valid-many_logloss:0.39938
# [151]	train-many_logloss:0.04522	test-many_logloss:0.11254	valid-many_logloss:0.11104
# {'alpha': 0, 'beta_eta': 0.012588600896345226, 'btype': 'Rn', 'colsample_bylevel': 0.5547269545129563, 'colsample_bytree': 0.9843635186756493, 'eta': 0.5949933323999959, 'eval_metric': ('many_logloss',), 'extra_dims': 4, 'gamma': 0.00013347887526644314, 'lambda': 0, 'max_depth': 9, 'min_child_weight': 7.283920920982167e-06, 'objective': 'manybinary:logistic', 'subsample': 0.9927469091208938, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.87688	test-many_logloss:0.89621	valid-many_logloss:0.89758
# [19]	train-many_logloss:inf	test-many_logloss:inf	valid-many_logloss:inf
# {'alpha': 1.0366863221923632, 'beta_eta': 0.13640103803528691, 'btype': 'Rn', 'colsample_bylevel': 0.6367989155272455, 'colsample_bytree': 0.6974194337846622, 'eta': 0.3029677824305006, 'eval_metric': ('many_logloss',), 'extra_dims': 6, 'gamma': 1.5812851156161036, 'lambda': 1.2783614674881826e-06, 'max_depth': 5, 'min_child_weight': 2.558034001077105, 'objective': 'manybinary:logistic', 'subsample': 0.7481581307597385, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.56512	test-many_logloss:0.56372	valid-many_logloss:0.56473
# [19]	train-many_logloss:nan	test-many_logloss:inf	valid-many_logloss:inf
# {'alpha': 0.0015268888255807838, 'beta_eta': 0.20179405533498707, 'btype': 'R', 'colsample_bylevel': 0.822829897275416, 'colsample_bytree': 0.8661025998484644, 'eta': 0.011434936316016709, 'eval_metric': ('many_logloss',), 'extra_dims': 1, 'gamma': 0, 'lambda': 2.091554134375915, 'max_depth': 8, 'min_child_weight': 1.6723514459697203e-05, 'objective': 'manybinary:logistic', 'subsample': 0.6325684178842439, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.63390	test-many_logloss:0.63397	valid-many_logloss:0.63384
# [52]	train-many_logloss:0.01677	test-many_logloss:0.11754	valid-many_logloss:0.12334
# {'alpha': 7.049352314660277e-05, 'beta_eta': 0.12137127268126893, 'btype': 'Rn', 'colsample_bylevel': 0.9439090074967231, 'colsample_bytree': 0.5525925639927433, 'eta': 0.0009915520889927426, 'eval_metric': ('many_logloss',), 'extra_dims': 3, 'gamma': 0, 'lambda': 0.004073992634408555, 'max_depth': 2, 'min_child_weight': 1.3633143522854873e-06, 'objective': 'manybinary:logistic', 'subsample': 0.9311207654760087, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.68675	test-many_logloss:0.68676	valid-many_logloss:0.68675
# [63]	train-many_logloss:0.16497	test-many_logloss:0.17519	valid-many_logloss:0.17782
# {'alpha': 8.581958439353927e-05, 'beta_eta': 0.4437471588909133, 'btype': 'R', 'colsample_bylevel': 0.787125082065971, 'colsample_bytree': 0.5243474561426513, 'eta': 0.8099003407203538, 'eval_metric': ('many_logloss',), 'extra_dims': 3, 'gamma': 7.475715249737038e-05, 'lambda': 0.0003639646509775927, 'max_depth': 7, 'min_child_weight': 0.09759627970810976, 'objective': 'manybinary:logistic', 'subsample': 0.553442319017114, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:1.23065	test-many_logloss:1.24387	valid-many_logloss:1.24909
# [20]	train-many_logloss:inf	test-many_logloss:inf	valid-many_logloss:inf
# {'alpha': 0, 'beta_eta': 0.1292065517955496, 'btype': 'Rn', 'colsample_bylevel': 0.7061150549075759, 'colsample_bytree': 0.5843009197915733, 'eta': 0.002630107568123181, 'eval_metric': ('many_logloss',), 'extra_dims': 2, 'gamma': 6.947115616562489, 'lambda': 0, 'max_depth': 10, 'min_child_weight': 41.36978142254861, 'objective': 'manybinary:logistic', 'subsample': 0.7453409993563878, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.67767	test-many_logloss:0.67771	valid-many_logloss:0.67767
# [67]	train-many_logloss:0.10260	test-many_logloss:0.14747	valid-many_logloss:0.14355
# {'alpha': 0, 'beta_eta': 0.11363289588177274, 'btype': 'Rn', 'colsample_bylevel': 0.8017715093779021, 'colsample_bytree': 0.7625111741024486, 'eta': 0.007606220882567551, 'eval_metric': ('many_logloss',), 'extra_dims': 4, 'gamma': 0.001053204847233351, 'lambda': 0.23316250775856961, 'max_depth': 1, 'min_child_weight': 1.9088058756735313e-07, 'objective': 'manybinary:logistic', 'subsample': 0.5239057927863935, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.64132	test-many_logloss:0.64131	valid-many_logloss:0.64135
# [71]	train-many_logloss:0.14733	test-many_logloss:0.15621	valid-many_logloss:0.15745
# {'alpha': 0, 'beta_eta': 0.2023070079269739, 'btype': 'I', 'colsample_bylevel': 0.98982155285091, 'colsample_bytree': 0.8137063678634311, 'eta': 0.021437825449384364, 'eval_metric': ('many_logloss',), 'extra_dims': 2, 'gamma': 0, 'lambda': 0, 'max_depth': 5, 'min_child_weight': 2.5600171535202e-07, 'objective': 'manybinary:logistic', 'subsample': 0.7174114308249333, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.65207	test-many_logloss:0.65289	valid-many_logloss:0.65272
# [40]	train-many_logloss:0.01864	test-many_logloss:0.14809	valid-many_logloss:0.14036
# {'alpha': 0, 'beta_eta': 0.675621539900281, 'btype': 'I', 'colsample_bylevel': 0.6189065258301154, 'colsample_bytree': 0.7882001782331782, 'eta': 0.003770077706590942, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0.0006381725365621713, 'lambda': 0, 'max_depth': 1, 'min_child_weight': 0.05537987461653371, 'objective': 'manybinary:logistic', 'subsample': 0.6537419349296045, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.69056	test-many_logloss:0.69057	valid-many_logloss:0.69057
# [24]	train-many_logloss:inf	test-many_logloss:inf	valid-many_logloss:inf
# {'alpha': 0, 'beta_eta': 0.06489049340354942, 'btype': 'I', 'colsample_bylevel': 0.8729133438901646, 'colsample_bytree': 0.5205123603280772, 'eta': 0.0309650866085196, 'eval_metric': ('many_logloss',), 'extra_dims': 5, 'gamma': 0, 'lambda': 7.910525070154376e-06, 'max_depth': 3, 'min_child_weight': 7.405155036744976e-05, 'objective': 'manybinary:logistic', 'subsample': 0.6231629412057431, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.59477	test-many_logloss:0.59465	valid-many_logloss:0.59508
# [105]	train-many_logloss:0.01681	test-many_logloss:0.07895	valid-many_logloss:0.07909
# {'alpha': 0.014845224338582359, 'beta_eta': 0.03770137496335071, 'btype': 'Rn', 'colsample_bylevel': 0.7211698432094364, 'colsample_bytree': 0.712394975511369, 'eta': 0.008477424619483462, 'eval_metric': ('many_logloss',), 'extra_dims': 1, 'gamma': 0, 'lambda': 0, 'max_depth': 3, 'min_child_weight': 32.756265617720345, 'objective': 'manybinary:logistic', 'subsample': 0.6995489417449295, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.65063	test-many_logloss:0.65073	valid-many_logloss:0.65066
# [200]	train-many_logloss:0.05093	test-many_logloss:0.08856	valid-many_logloss:0.08885
# [207]	train-many_logloss:0.04949	test-many_logloss:0.08868	valid-many_logloss:0.08892
# {'alpha': 2.7324514268482383, 'beta_eta': 0.08036958137175818, 'btype': 'R', 'colsample_bylevel': 0.7987531851832483, 'colsample_bytree': 0.7299740823920091, 'eta': 0.06030778497723384, 'eval_metric': ('many_logloss',), 'extra_dims': 3, 'gamma': 0, 'lambda': 0, 'max_depth': 8, 'min_child_weight': 0.00023882505207060682, 'objective': 'manybinary:logistic', 'subsample': 0.8750385697829414, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.42939	test-many_logloss:0.42994	valid-many_logloss:0.42986
# [63]	train-many_logloss:0.00074	test-many_logloss:0.05838	valid-many_logloss:0.05892
# NEW BEST VALUE!
# {'alpha': 0, 'beta_eta': 0.009060610135766442, 'btype': 'I', 'colsample_bylevel': 0.7332732947918047, 'colsample_bytree': 0.5030735772414907, 'eta': 0.0015245875835189877, 'eval_metric': ('many_logloss',), 'extra_dims': 7, 'gamma': 9.066632495478617e-06, 'lambda': 0, 'max_depth': 3, 'min_child_weight': 135.18110003620356, 'objective': 'manybinary:logistic', 'subsample': 0.5593100367488764, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.68656	test-many_logloss:0.68657	valid-many_logloss:0.68655
# [200]	train-many_logloss:0.16392	test-many_logloss:0.17351	valid-many_logloss:0.17375
# [400]	train-many_logloss:0.08620	test-many_logloss:0.10247	valid-many_logloss:0.10289
# [499]	train-many_logloss:0.07107	test-many_logloss:0.09163	valid-many_logloss:0.09182
# {'alpha': 9.442657203270879e-05, 'beta_eta': 0.17396370377116593, 'btype': 'I', 'colsample_bylevel': 0.7781226592895327, 'colsample_bytree': 0.6398164878102375, 'eta': 0.0041851001124752684, 'eval_metric': ('many_logloss',), 'extra_dims': 7, 'gamma': 5.825640644469816e-06, 'lambda': 0, 'max_depth': 8, 'min_child_weight': 0.00537473915613328, 'objective': 'manybinary:logistic', 'subsample': 0.5391816076002862, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.67538	test-many_logloss:0.67573	valid-many_logloss:0.67565
# [42]	train-many_logloss:0.01467	test-many_logloss:0.11852	valid-many_logloss:0.12609
# {'alpha': 0, 'beta_eta': 0.7112779064038146, 'btype': 'I', 'colsample_bylevel': 0.980487461508577, 'colsample_bytree': 0.872601457169579, 'eta': 0.46040749038190176, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0, 'lambda': 0, 'max_depth': 5, 'min_child_weight': 0.0003681699610575285, 'objective': 'manybinary:logistic', 'subsample': 0.7369430758094139, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.38222	test-many_logloss:0.39869	valid-many_logloss:0.39703
# [22]	train-many_logloss:inf	test-many_logloss:inf	valid-many_logloss:inf
# {'alpha': 0, 'beta_eta': 0.004046103790871514, 'btype': 'I', 'colsample_bylevel': 0.7818800515438491, 'colsample_bytree': 0.7724637498474807, 'eta': 0.008563159803242014, 'eval_metric': ('many_logloss',), 'extra_dims': 4, 'gamma': 1.138875246733091, 'lambda': 0.004929740945608459, 'max_depth': 8, 'min_child_weight': 1.2189098145853323e-06, 'objective': 'manybinary:logistic', 'subsample': 0.92406704328224, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.66844	test-many_logloss:0.66914	valid-many_logloss:0.66902
# [200]	train-many_logloss:0.02891	test-many_logloss:0.08364	valid-many_logloss:0.08714
# [400]	train-many_logloss:0.00771	test-many_logloss:0.06760	valid-many_logloss:0.07087
# [474]	train-many_logloss:0.00583	test-many_logloss:0.06742	valid-many_logloss:0.07066
# {'alpha': 0, 'beta_eta': 0.008940815077581921, 'btype': 'R', 'colsample_bylevel': 0.947651214492775, 'colsample_bytree': 0.8633457836387857, 'eta': 0.3977029463511548, 'eval_metric': ('many_logloss',), 'extra_dims': 7, 'gamma': 0.003128466805888169, 'lambda': 0, 'max_depth': 6, 'min_child_weight': 23.81766245704533, 'objective': 'manybinary:logistic', 'subsample': 0.8289219023831419, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.81905	test-many_logloss:0.82068	valid-many_logloss:0.82202
# [20]	train-many_logloss:nan	test-many_logloss:nan	valid-many_logloss:nan
# {'alpha': 0, 'beta_eta': 0.7189262806817021, 'btype': 'Rn', 'colsample_bylevel': 0.8025654416649992, 'colsample_bytree': 0.8748052006921443, 'eta': 0.009393489875683971, 'eval_metric': ('many_logloss',), 'extra_dims': 3, 'gamma': 0, 'lambda': 0, 'max_depth': 2, 'min_child_weight': 0.013234942416650719, 'objective': 'manybinary:logistic', 'subsample': 0.8694541664166509, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.63477	test-many_logloss:0.63487	valid-many_logloss:0.63469
# [26]	train-many_logloss:inf	test-many_logloss:inf	valid-many_logloss:inf
# {'alpha': 1.2866021697680973e-07, 'beta_eta': 0.0016060730652605972, 'btype': 'In', 'colsample_bylevel': 0.6691714474136173, 'colsample_bytree': 0.9253629229741183, 'eta': 0.09251058420349038, 'eval_metric': ('many_logloss',), 'extra_dims': 2, 'gamma': 0, 'lambda': 0, 'max_depth': 4, 'min_child_weight': 0.0006473488594456236, 'objective': 'manybinary:logistic', 'subsample': 0.8009418233768887, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.53538	test-many_logloss:0.53718	valid-many_logloss:0.53701
# [150]	train-many_logloss:0.00237	test-many_logloss:0.06019	valid-many_logloss:0.06082
# {'alpha': 6.193318965432613, 'beta_eta': 0.0016968842567052704, 'btype': 'In', 'colsample_bylevel': 0.665635469009916, 'colsample_bytree': 0.6329367489721852, 'eta': 0.11496412241179467, 'eval_metric': ('many_logloss',), 'extra_dims': 2, 'gamma': 0, 'lambda': 0, 'max_depth': 4, 'min_child_weight': 0.0007864917623392554, 'objective': 'manybinary:logistic', 'subsample': 0.8250681460951041, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.52374	test-many_logloss:0.52509	valid-many_logloss:0.52527
# [19]	train-many_logloss:inf	test-many_logloss:inf	valid-many_logloss:inf
# {'alpha': 1.9502601025950633e-07, 'beta_eta': 0.022203359955243605, 'btype': 'In', 'colsample_bylevel': 0.5347468997599942, 'colsample_bytree': 0.9659789074381175, 'eta': 0.09852342968424244, 'eval_metric': ('many_logloss',), 'extra_dims': 6, 'gamma': 0, 'lambda': 0, 'max_depth': 4, 'min_child_weight': 0.0003469319404566836, 'objective': 'manybinary:logistic', 'subsample': 0.7995363264451619, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.40307	test-many_logloss:0.40546	valid-many_logloss:0.40515
# [84]	train-many_logloss:0.00171	test-many_logloss:0.05824	valid-many_logloss:0.06087
# {'alpha': 0.08923677519648028, 'beta_eta': 0.02123098842309264, 'btype': 'In', 'colsample_bylevel': 0.5136423073788041, 'colsample_bytree': 0.9952838723720001, 'eta': 0.08935692010593531, 'eval_metric': ('many_logloss',), 'extra_dims': 6, 'gamma': 0, 'lambda': 0, 'max_depth': 4, 'min_child_weight': 0.5840413635382012, 'objective': 'manybinary:logistic', 'subsample': 0.9022196739943122, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.43121	test-many_logloss:0.43338	valid-many_logloss:0.43300
# [105]	train-many_logloss:0.00385	test-many_logloss:0.05653	valid-many_logloss:0.05733
# {'alpha': 0.17080131938735654, 'beta_eta': 0.0318191062086167, 'btype': 'In', 'colsample_bylevel': 0.8800599947650888, 'colsample_bytree': 0.661273049374225, 'eta': 0.04532681424547701, 'eval_metric': ('many_logloss',), 'extra_dims': 6, 'gamma': 0, 'lambda': 0, 'max_depth': 8, 'min_child_weight': 1.0820260582271848, 'objective': 'manybinary:logistic', 'subsample': 0.9484515874381598, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.54382	test-many_logloss:0.54480	valid-many_logloss:0.54446
# [94]	train-many_logloss:0.00181	test-many_logloss:0.05061	valid-many_logloss:0.05388
# NEW BEST VALUE!
# 100%|██████████| 25/25 [12:33<00:00, 30.13s/trial, best loss: 0.05284]
# ...
# [0]	train-many_logloss:0.34929	test-many_logloss:0.35258	valid-many_logloss:0.35131
# [83]	train-many_logloss:0.00133	test-many_logloss:0.07568	valid-many_logloss:0.07181
# 100%|██████████| 25/25 [11:22<00:00, 27.28s/trial, best loss: 0.052975]
# {'alpha': 8.813057946902575e-07, 'beta_eta': 0.0016692834513794938, 'btype': 'R', 'colsample_bylevel': 0.7489980469009814, 'colsample_bytree': 0.9420146676089547, 'eta': 0.0070706936561268224, 'eval_metric': ('many_logloss',), 'extra_dims': 2, 'gamma': 0, 'lambda': 0, 'max_depth': 5, 'min_child_weight': 2.1041667775099838e-05, 'objective': 'manybinary:logistic', 'subsample': 0.6262451727083667, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.65198	test-many_logloss:0.65196	valid-many_logloss:0.65212
# [200]	train-many_logloss:0.10164	test-many_logloss:0.12623	valid-many_logloss:0.12873
# [400]	train-many_logloss:0.03322	test-many_logloss:0.06992	valid-many_logloss:0.07124
# [499]	train-many_logloss:0.02014	test-many_logloss:0.06035	valid-many_logloss:0.06149
# NEW BEST VALUE!
# {'alpha': 0, 'beta_eta': 0.07375799600401638, 'btype': 'I', 'colsample_bylevel': 0.8357246683355697, 'colsample_bytree': 0.7491187395188089, 'eta': 0.605518780660455, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0, 'lambda': 0, 'max_depth': 5, 'min_child_weight': 118.844312919608, 'objective': 'manybinary:logistic', 'subsample': 0.6525233714163394, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.39745	test-many_logloss:0.39657	valid-many_logloss:0.39779
# [79]	train-many_logloss:0.09116	test-many_logloss:0.13035	valid-many_logloss:0.13504
# {'alpha': 0, 'beta_eta': 0.012588600896345226, 'btype': 'Rn', 'colsample_bylevel': 0.5547269545129563, 'colsample_bytree': 0.9843635186756493, 'eta': 0.5949933323999959, 'eval_metric': ('many_logloss',), 'extra_dims': 4, 'gamma': 0.00013347887526644314, 'lambda': 0, 'max_depth': 9, 'min_child_weight': 7.283920920982167e-06, 'objective': 'manybinary:logistic', 'subsample': 0.9927469091208938, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.96313	test-many_logloss:0.98192	valid-many_logloss:0.98452
# [20]	train-many_logloss:inf	test-many_logloss:inf	valid-many_logloss:inf
# {'alpha': 1.0366863221923632, 'beta_eta': 0.13640103803528691, 'btype': 'Rn', 'colsample_bylevel': 0.6367989155272455, 'colsample_bytree': 0.6974194337846622, 'eta': 0.3029677824305006, 'eval_metric': ('many_logloss',), 'extra_dims': 6, 'gamma': 1.5812851156161036, 'lambda': 1.2783614674881826e-06, 'max_depth': 5, 'min_child_weight': 2.558034001077105, 'objective': 'manybinary:logistic', 'subsample': 0.7481581307597385, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.58247	test-many_logloss:0.58434	valid-many_logloss:0.58211
# [20]	train-many_logloss:inf	test-many_logloss:nan	valid-many_logloss:inf
# {'alpha': 0.0015268888255807838, 'beta_eta': 0.20179405533498707, 'btype': 'R', 'colsample_bylevel': 0.822829897275416, 'colsample_bytree': 0.8661025998484644, 'eta': 0.011434936316016709, 'eval_metric': ('many_logloss',), 'extra_dims': 1, 'gamma': 0, 'lambda': 2.091554134375915, 'max_depth': 8, 'min_child_weight': 1.6723514459697203e-05, 'objective': 'manybinary:logistic', 'subsample': 0.6325684178842439, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.63509	test-many_logloss:0.63519	valid-many_logloss:0.63514
# [20]	train-many_logloss:inf	test-many_logloss:inf	valid-many_logloss:inf
# {'alpha': 7.049352314660277e-05, 'beta_eta': 0.12137127268126893, 'btype': 'Rn', 'colsample_bylevel': 0.9439090074967231, 'colsample_bytree': 0.5525925639927433, 'eta': 0.0009915520889927426, 'eval_metric': ('many_logloss',), 'extra_dims': 3, 'gamma': 0, 'lambda': 0.004073992634408555, 'max_depth': 2, 'min_child_weight': 1.3633143522854873e-06, 'objective': 'manybinary:logistic', 'subsample': 0.9311207654760087, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.68690	test-many_logloss:0.68690	valid-many_logloss:0.68690
# [62]	train-many_logloss:0.16115	test-many_logloss:0.17940	valid-many_logloss:0.17386
# {'alpha': 8.581958439353927e-05, 'beta_eta': 0.4437471588909133, 'btype': 'R', 'colsample_bylevel': 0.787125082065971, 'colsample_bytree': 0.5243474561426513, 'eta': 0.8099003407203538, 'eval_metric': ('many_logloss',), 'extra_dims': 3, 'gamma': 7.475715249737038e-05, 'lambda': 0.0003639646509775927, 'max_depth': 7, 'min_child_weight': 0.09759627970810976, 'objective': 'manybinary:logistic', 'subsample': 0.553442319017114, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:1.17732	test-many_logloss:1.18540	valid-many_logloss:1.19462
# [19]	train-many_logloss:inf	test-many_logloss:inf	valid-many_logloss:inf
# {'alpha': 0, 'beta_eta': 0.1292065517955496, 'btype': 'Rn', 'colsample_bylevel': 0.7061150549075759, 'colsample_bytree': 0.5843009197915733, 'eta': 0.002630107568123181, 'eval_metric': ('many_logloss',), 'extra_dims': 2, 'gamma': 6.947115616562489, 'lambda': 0, 'max_depth': 10, 'min_child_weight': 41.36978142254861, 'objective': 'manybinary:logistic', 'subsample': 0.7453409993563878, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.67828	test-many_logloss:0.67826	valid-many_logloss:0.67827
# [69]	train-many_logloss:0.09982	test-many_logloss:0.14232	valid-many_logloss:0.13915
# {'alpha': 0, 'beta_eta': 0.11363289588177274, 'btype': 'Rn', 'colsample_bylevel': 0.8017715093779021, 'colsample_bytree': 0.7625111741024486, 'eta': 0.007606220882567551, 'eval_metric': ('many_logloss',), 'extra_dims': 4, 'gamma': 0.001053204847233351, 'lambda': 0.23316250775856961, 'max_depth': 1, 'min_child_weight': 1.9088058756735313e-07, 'objective': 'manybinary:logistic', 'subsample': 0.5239057927863935, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.64299	test-many_logloss:0.64301	valid-many_logloss:0.64293
# [69]	train-many_logloss:0.16602	test-many_logloss:0.17301	valid-many_logloss:0.17607
# {'alpha': 0, 'beta_eta': 0.2023070079269739, 'btype': 'I', 'colsample_bylevel': 0.98982155285091, 'colsample_bytree': 0.8137063678634311, 'eta': 0.021437825449384364, 'eval_metric': ('many_logloss',), 'extra_dims': 2, 'gamma': 0, 'lambda': 0, 'max_depth': 5, 'min_child_weight': 2.5600171535202e-07, 'objective': 'manybinary:logistic', 'subsample': 0.7174114308249333, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.65526	test-many_logloss:0.65581	valid-many_logloss:0.65600
# [39]	train-many_logloss:0.02126	test-many_logloss:0.12996	valid-many_logloss:0.13127
# {'alpha': 0, 'beta_eta': 0.675621539900281, 'btype': 'I', 'colsample_bylevel': 0.6189065258301154, 'colsample_bytree': 0.7882001782331782, 'eta': 0.003770077706590942, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0.0006381725365621713, 'lambda': 0, 'max_depth': 1, 'min_child_weight': 0.05537987461653371, 'objective': 'manybinary:logistic', 'subsample': 0.6537419349296045, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.69055	test-many_logloss:0.69055	valid-many_logloss:0.69056
# [25]	train-many_logloss:0.23249	test-many_logloss:0.24149	valid-many_logloss:0.24287
# {'alpha': 0, 'beta_eta': 0.06489049340354942, 'btype': 'I', 'colsample_bylevel': 0.8729133438901646, 'colsample_bytree': 0.5205123603280772, 'eta': 0.0309650866085196, 'eval_metric': ('many_logloss',), 'extra_dims': 5, 'gamma': 0, 'lambda': 7.910525070154376e-06, 'max_depth': 3, 'min_child_weight': 7.405155036744976e-05, 'objective': 'manybinary:logistic', 'subsample': 0.6231629412057431, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.59788	test-many_logloss:0.59791	valid-many_logloss:0.59852
# [106]	train-many_logloss:0.01714	test-many_logloss:0.07723	valid-many_logloss:0.07986
# {'alpha': 0.014845224338582359, 'beta_eta': 0.03770137496335071, 'btype': 'Rn', 'colsample_bylevel': 0.7211698432094364, 'colsample_bytree': 0.712394975511369, 'eta': 0.008477424619483462, 'eval_metric': ('many_logloss',), 'extra_dims': 1, 'gamma': 0, 'lambda': 0, 'max_depth': 3, 'min_child_weight': 32.756265617720345, 'objective': 'manybinary:logistic', 'subsample': 0.6995489417449295, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.64692	test-many_logloss:0.64696	valid-many_logloss:0.64696
# [200]	train-many_logloss:0.05327	test-many_logloss:0.09637	valid-many_logloss:0.09216
# [229]	train-many_logloss:0.04710	test-many_logloss:0.09681	valid-many_logloss:0.09243
# {'alpha': 2.7324514268482383, 'beta_eta': 0.08036958137175818, 'btype': 'R', 'colsample_bylevel': 0.7987531851832483, 'colsample_bytree': 0.7299740823920091, 'eta': 0.06030778497723384, 'eval_metric': ('many_logloss',), 'extra_dims': 3, 'gamma': 0, 'lambda': 0, 'max_depth': 8, 'min_child_weight': 0.00023882505207060682, 'objective': 'manybinary:logistic', 'subsample': 0.8750385697829414, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.43055	test-many_logloss:0.43011	valid-many_logloss:0.43051
# [66]	train-many_logloss:0.00065	test-many_logloss:0.05543	valid-many_logloss:0.05546
# NEW BEST VALUE!
# {'alpha': 0, 'beta_eta': 0.009060610135766442, 'btype': 'I', 'colsample_bylevel': 0.7332732947918047, 'colsample_bytree': 0.5030735772414907, 'eta': 0.0015245875835189877, 'eval_metric': ('many_logloss',), 'extra_dims': 7, 'gamma': 9.066632495478617e-06, 'lambda': 0, 'max_depth': 3, 'min_child_weight': 135.18110003620356, 'objective': 'manybinary:logistic', 'subsample': 0.5593100367488764, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.68699	test-many_logloss:0.68698	valid-many_logloss:0.68699
# [200]	train-many_logloss:0.16255	test-many_logloss:0.16991	valid-many_logloss:0.17175
# [400]	train-many_logloss:0.08542	test-many_logloss:0.10051	valid-many_logloss:0.10075
# [499]	train-many_logloss:0.07086	test-many_logloss:0.09094	valid-many_logloss:0.09025
# {'alpha': 9.442657203270879e-05, 'beta_eta': 0.17396370377116593, 'btype': 'I', 'colsample_bylevel': 0.7781226592895327, 'colsample_bytree': 0.6398164878102375, 'eta': 0.0041851001124752684, 'eval_metric': ('many_logloss',), 'extra_dims': 7, 'gamma': 5.825640644469816e-06, 'lambda': 0, 'max_depth': 8, 'min_child_weight': 0.00537473915613328, 'objective': 'manybinary:logistic', 'subsample': 0.5391816076002862, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.67377	test-many_logloss:0.67404	valid-many_logloss:0.67408
# [43]	train-many_logloss:0.01489	test-many_logloss:0.13784	valid-many_logloss:0.13216
# {'alpha': 0, 'beta_eta': 0.7112779064038146, 'btype': 'I', 'colsample_bylevel': 0.980487461508577, 'colsample_bytree': 0.872601457169579, 'eta': 0.46040749038190176, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0, 'lambda': 0, 'max_depth': 5, 'min_child_weight': 0.0003681699610575285, 'objective': 'manybinary:logistic', 'subsample': 0.7369430758094139, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.38422	test-many_logloss:0.39631	valid-many_logloss:0.39897
# [22]	train-many_logloss:nan	test-many_logloss:inf	valid-many_logloss:inf
# {'alpha': 0, 'beta_eta': 0.004046103790871514, 'btype': 'I', 'colsample_bylevel': 0.7818800515438491, 'colsample_bytree': 0.7724637498474807, 'eta': 0.008563159803242014, 'eval_metric': ('many_logloss',), 'extra_dims': 4, 'gamma': 1.138875246733091, 'lambda': 0.004929740945608459, 'max_depth': 8, 'min_child_weight': 1.2189098145853323e-06, 'objective': 'manybinary:logistic', 'subsample': 0.92406704328224, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.66868	test-many_logloss:0.66931	valid-many_logloss:0.66930
# [200]	train-many_logloss:0.02831	test-many_logloss:0.08096	valid-many_logloss:0.08385
# [400]	train-many_logloss:0.00770	test-many_logloss:0.06624	valid-many_logloss:0.06845
# [446]	train-many_logloss:0.00650	test-many_logloss:0.06623	valid-many_logloss:0.06837
# {'alpha': 0, 'beta_eta': 0.008940815077581921, 'btype': 'R', 'colsample_bylevel': 0.947651214492775, 'colsample_bytree': 0.8633457836387857, 'eta': 0.3977029463511548, 'eval_metric': ('many_logloss',), 'extra_dims': 7, 'gamma': 0.003128466805888169, 'lambda': 0, 'max_depth': 6, 'min_child_weight': 23.81766245704533, 'objective': 'manybinary:logistic', 'subsample': 0.8289219023831419, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.77340	test-many_logloss:0.76885	valid-many_logloss:0.77623
# [19]	train-many_logloss:nan	test-many_logloss:nan	valid-many_logloss:nan
# {'alpha': 0, 'beta_eta': 0.7189262806817021, 'btype': 'Rn', 'colsample_bylevel': 0.8025654416649992, 'colsample_bytree': 0.8748052006921443, 'eta': 0.009393489875683971, 'eval_metric': ('many_logloss',), 'extra_dims': 3, 'gamma': 0, 'lambda': 0, 'max_depth': 2, 'min_child_weight': 0.013234942416650719, 'objective': 'manybinary:logistic', 'subsample': 0.8694541664166509, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.63684	test-many_logloss:0.63681	valid-many_logloss:0.63687
# [25]	train-many_logloss:inf	test-many_logloss:inf	valid-many_logloss:inf
# {'alpha': 1.2866021697680973e-07, 'beta_eta': 0.0016060730652605972, 'btype': 'In', 'colsample_bylevel': 0.6691714474136173, 'colsample_bytree': 0.9253629229741183, 'eta': 0.09251058420349038, 'eval_metric': ('many_logloss',), 'extra_dims': 2, 'gamma': 0, 'lambda': 0, 'max_depth': 4, 'min_child_weight': 0.0006473488594456236, 'objective': 'manybinary:logistic', 'subsample': 0.8009418233768887, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.54248	test-many_logloss:0.54404	valid-many_logloss:0.54410
# [131]	train-many_logloss:0.00445	test-many_logloss:0.06164	valid-many_logloss:0.06052
# {'alpha': 6.193318965432613, 'beta_eta': 0.0016968842567052704, 'btype': 'In', 'colsample_bylevel': 0.665635469009916, 'colsample_bytree': 0.6329367489721852, 'eta': 0.11496412241179467, 'eval_metric': ('many_logloss',), 'extra_dims': 2, 'gamma': 0, 'lambda': 0, 'max_depth': 4, 'min_child_weight': 0.0007864917623392554, 'objective': 'manybinary:logistic', 'subsample': 0.8250681460951041, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.51228	test-many_logloss:0.51331	valid-many_logloss:0.51396
# [20]	train-many_logloss:inf	test-many_logloss:inf	valid-many_logloss:inf
# {'alpha': 1.9502601025950633e-07, 'beta_eta': 0.022203359955243605, 'btype': 'In', 'colsample_bylevel': 0.5347468997599942, 'colsample_bytree': 0.9659789074381175, 'eta': 0.09852342968424244, 'eval_metric': ('many_logloss',), 'extra_dims': 6, 'gamma': 0, 'lambda': 0, 'max_depth': 4, 'min_child_weight': 0.0003469319404566836, 'objective': 'manybinary:logistic', 'subsample': 0.7995363264451619, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.42038	test-many_logloss:0.42206	valid-many_logloss:0.42215
# [87]	train-many_logloss:0.00138	test-many_logloss:0.06058	valid-many_logloss:0.06091
# {'alpha': 0.08923677519648028, 'beta_eta': 0.02123098842309264, 'btype': 'In', 'colsample_bylevel': 0.5136423073788041, 'colsample_bytree': 0.9952838723720001, 'eta': 0.08935692010593531, 'eval_metric': ('many_logloss',), 'extra_dims': 6, 'gamma': 0, 'lambda': 0, 'max_depth': 4, 'min_child_weight': 0.5840413635382012, 'objective': 'manybinary:logistic', 'subsample': 0.9022196739943122, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.42795	test-many_logloss:0.42903	valid-many_logloss:0.42914
# [103]	train-many_logloss:0.00426	test-many_logloss:0.05758	valid-many_logloss:0.05618
# {'alpha': 0.17080131938735654, 'beta_eta': 0.0318191062086167, 'btype': 'In', 'colsample_bylevel': 0.8800599947650888, 'colsample_bytree': 0.661273049374225, 'eta': 0.04532681424547701, 'eval_metric': ('many_logloss',), 'extra_dims': 6, 'gamma': 0, 'lambda': 0, 'max_depth': 8, 'min_child_weight': 1.0820260582271848, 'objective': 'manybinary:logistic', 'subsample': 0.9484515874381598, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.54503	test-many_logloss:0.54554	valid-many_logloss:0.54595
# [95]	train-many_logloss:0.00179	test-many_logloss:0.05533	valid-many_logloss:0.05446
# 100%|██████████| 25/25 [10:59<00:00, 26.36s/trial, best loss: 0.051633]

# %%
import pandas as pd
pd.concat([
    pd.Series(r).to_frame().T for r in results
], axis=0).to_csv('./mnist_wxgb_results_paper_2.csv', index=False)
