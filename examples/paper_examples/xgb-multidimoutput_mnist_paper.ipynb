# %%
import sys
import time
from wideboost.wrappers import wxgb
import numpy as np
import xgboost as xgb

import tensorflow_datasets as tfds
from matplotlib import pyplot as plt

(ds_train, ds_test), ds_info = tfds.load(
    'mnist',
    split=['train', 'test'],
    shuffle_files=False,
    as_supervised=True,
    with_info=True,
)

for i in ds_train.batch(60000):
    a = i
    
for i in ds_test.batch(60000):
    b = i

# %%
xtrain = a[0].numpy().reshape([-1,28*28])
ytrain = a[1].numpy()

xtest = b[0].numpy().reshape([-1,28*28])
ytest = b[1].numpy()

# %%
def _onehot(Y):
    b = np.zeros((Y.shape[0], Y.max().astype(int)+1))
    b[np.arange(Y.shape[0]),Y.astype(int).flatten()] = 1
    return b

# %%
def get_data(seed):
    np.random.seed(seed)
    train_idx = np.random.choice(range(xtrain.shape[0]), round(xtrain.shape[0] * 0.7), replace=False)
    valid_idx = np.array(list(set(range(xtrain.shape[0])) - set(train_idx)))
    train_idx = np.random.choice(train_idx, 3_000, replace=False)
    valid_idx = np.random.choice(valid_idx, 2_000, replace=False)

    test_idx = np.random.choice(range(xtest.shape[0]), 1_000, replace=False)

    features = np.random.choice(range(xtrain.shape[1]), 200, replace=False)


    y_train = _onehot(ytrain[train_idx])
    y_valid = _onehot(ytrain[valid_idx])
    y_test =  _onehot(ytest[test_idx])

    return (
        xtrain[train_idx[:,None], features],
        xtrain[valid_idx[:,None], features],
        xtest[test_idx[:,None], features], y_train, y_valid, y_test
    )

# %%
from hyperopt import fmin, tpe, hp, STATUS_OK, space_eval
import os

iters = 30
results = []
for est in range(iters):

    t0 = time.time()
    x_train, x_valid, x_test, y_train, y_valid, y_test = get_data(1000 + est)
    watchlist = [
        ((x_train, y_train),'train'),
        ((x_test, y_test), 'test'),
        ((x_valid, y_valid), 'valid')
    ]

    best_val = 1000.0
    xgb_test_val = 1000.0
    xgb_param = {}
    nrounds = 0

    def objective(param):
        global best_val
        global xgb_test_val
        global xgb_param
        global nrounds
        num_round = 500
        param['output_dim'] = 10
        param['nthread'] = 2
        print(param)

        xgb_results = {}
        wbst = wxgb.fit(
            x_train, y_train,
            param, num_round, watchlist,
            evals_result=xgb_results,
            early_stopping_rounds=20,
            verbose_eval=200
        )
        
        if (min(xgb_results['valid']['many_logloss'])) < best_val:
            print("NEW BEST VALUE!")
            best_val = min(xgb_results['valid']['many_logloss'])
            xgb_test_val = xgb_results['test']['many_logloss'][
                np.argmin(xgb_results['valid']['many_logloss'])
            ]
            xgb_param = param
            nrounds = np.argmin(xgb_results['valid']['many_logloss']) + 1

        return {'loss': min(xgb_results['valid']['many_logloss']), 'status': STATUS_OK }

    spc = {
        'btype': hp.choice('btype',['I']),
        'extra_dims': hp.choice('extra_dims',[0]),
        'objective': hp.choice('objective',['manybinary:logistic']),
        'eval_metric':hp.choice('eval_metric',[['many_logloss']]),
        'eta': hp.loguniform('eta', -7, 0),
        'beta_eta': hp.choice('beta_eta',[0]),
        'max_depth' : hp.choice('max_depth',range(1,11)),
        'subsample': hp.uniform('subsample', 0.5, 1),
        'colsample_bytree': hp.uniform('colsample_bytree', 0.5, 1),
        'colsample_bylevel': hp.uniform('colsample_bylevel', 0.5, 1),
        'min_child_weight': hp.loguniform('min_child_weight', -16, 5),
        'alpha': hp.choice('alpha', [0, hp.loguniform('alpha_positive', -16, 2)]),
        'lambda': hp.choice('lambda', [0, hp.loguniform('lambda_positive', -16, 2)]),
        'gamma': hp.choice('gamma', [0, hp.loguniform('gamma_positive', -16, 2)])
    }
    os.environ['HYPEROPT_FMIN_SEED'] = '101010'
    best = fmin(objective,
        space=spc,
        algo=tpe.suggest,
        max_evals=25)
    t1 = time.time()
    results.append({
        'iter': est,
        'valid_logloss': best_val,
        'test_logloss': xgb_test_val,
        'num_rounds': nrounds,
        'time_diff': t1 - t0,
        'winning_param': xgb_param.copy()
    })
# Out:
# {'alpha': 0, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.7489980469009814, 'colsample_bytree': 0.9420146676089547, 'eta': 0.0070706936561268224, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0, 'lambda': 0, 'max_depth': 5, 'min_child_weight': 2.1041667775099838e-05, 'objective': 'manybinary:logistic', 'subsample': 0.6262451727083667, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.68707	test-many_logloss:0.68727	valid-many_logloss:0.68724
# [200]	train-many_logloss:0.18431	test-many_logloss:0.20818	valid-many_logloss:0.20662
# [400]	train-many_logloss:0.07420	test-many_logloss:0.11057	valid-many_logloss:0.10850
# [499]	train-many_logloss:0.05209	test-many_logloss:0.09254	valid-many_logloss:0.09044
# NEW BEST VALUE!
# {'alpha': 0, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.8357246683355697, 'colsample_bytree': 0.7491187395188089, 'eta': 0.605518780660455, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0, 'lambda': 0, 'max_depth': 5, 'min_child_weight': 118.844312919608, 'objective': 'manybinary:logistic', 'subsample': 0.6525233714163394, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.39941	test-many_logloss:0.39904	valid-many_logloss:0.40006
# [44]	train-many_logloss:0.25819	test-many_logloss:0.25789	valid-many_logloss:0.26013
# {'alpha': 3.7815423151500604e-05, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.5547269545129563, 'colsample_bytree': 0.9843635186756493, 'eta': 0.5949933323999959, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0.00013347887526644314, 'lambda': 0, 'max_depth': 9, 'min_child_weight': 7.283920920982167e-06, 'objective': 'manybinary:logistic', 'subsample': 0.9927469091208938, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.28021	test-many_logloss:0.33072	valid-many_logloss:0.33122
# [26]	train-many_logloss:0.00000	test-many_logloss:0.13422	valid-many_logloss:0.14164
# {'alpha': 0.003403374940376167, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.6367989155272455, 'colsample_bytree': 0.6974194337846622, 'eta': 0.3029677824305006, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 1.5812851156161036, 'lambda': 1.2783614674881826e-06, 'max_depth': 5, 'min_child_weight': 2.558034001077105, 'objective': 'manybinary:logistic', 'subsample': 0.7481581307597385, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.47599	test-many_logloss:0.48152	valid-many_logloss:0.48201
# [108]	train-many_logloss:0.01225	test-many_logloss:0.06834	valid-many_logloss:0.06733
# NEW BEST VALUE!
# {'alpha': 0, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.822829897275416, 'colsample_bytree': 0.8661025998484644, 'eta': 0.011434936316016709, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0, 'lambda': 2.091554134375915, 'max_depth': 8, 'min_child_weight': 1.6723514459697203e-05, 'objective': 'manybinary:logistic', 'subsample': 0.6325684178842439, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.68356	test-many_logloss:0.68388	valid-many_logloss:0.68393
# [200]	train-many_logloss:0.09980	test-many_logloss:0.13482	valid-many_logloss:0.13307
# [400]	train-many_logloss:0.03270	test-many_logloss:0.07920	valid-many_logloss:0.07775
# [499]	train-many_logloss:0.02245	test-many_logloss:0.07201	valid-many_logloss:0.07077
# {'alpha': 0, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.9439090074967231, 'colsample_bytree': 0.5525925639927433, 'eta': 0.0009915520889927426, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0, 'lambda': 0.004073992634408555, 'max_depth': 2, 'min_child_weight': 1.3633143522854873e-06, 'objective': 'manybinary:logistic', 'subsample': 0.9311207654760087, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.69242	test-many_logloss:0.69242	valid-many_logloss:0.69242
# [200]	train-many_logloss:0.56987	test-many_logloss:0.57062	valid-many_logloss:0.57062
# [400]	train-many_logloss:0.48166	test-many_logloss:0.48313	valid-many_logloss:0.48302
# [499]	train-many_logloss:0.44671	test-many_logloss:0.44852	valid-many_logloss:0.44838
# {'alpha': 0, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.787125082065971, 'colsample_bytree': 0.5243474561426513, 'eta': 0.8099003407203538, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 7.475715249737038e-05, 'lambda': 0.0003639646509775927, 'max_depth': 7, 'min_child_weight': 0.09759627970810976, 'objective': 'manybinary:logistic', 'subsample': 0.553442319017114, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.25865	test-many_logloss:0.29835	valid-many_logloss:0.29514
#  24%|██▍       | 6/25 [04:26<15:44, 49.71s/trial, best loss: 0.066817]
# ../wideboost/wideboost/evals/classification.py:82: RuntimeWarning: invalid value encountered in log
#   return -np.mean(np.log(p))
#
# ../wideboost/wideboost/evals/classification.py:82: RuntimeWarning: divide by zero encountered in log
#   return -np.mean(np.log(p))
#
# ../wideboost/wideboost/evals/classification.py:80: RuntimeWarning: overflow encountered in exp
#   p = 1/(1 + np.exp(-logits))
#
# ../wideboost/wideboost/objectives/manybinarylogloss.py:14: RuntimeWarning: overflow encountered in exp
#   P = 1 / (1 + np.exp(-logits))
# [23]	train-many_logloss:nan	test-many_logloss:nan	valid-many_logloss:nan
# {'alpha': 0, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.7061150549075759, 'colsample_bytree': 0.5843009197915733, 'eta': 0.002630107568123181, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 6.947115616562489, 'lambda': 0, 'max_depth': 10, 'min_child_weight': 41.36978142254861, 'objective': 'manybinary:logistic', 'subsample': 0.7453409993563878, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.69120	test-many_logloss:0.69121	valid-many_logloss:0.69122
# [200]	train-many_logloss:0.43210	test-many_logloss:0.43422	valid-many_logloss:0.43461
# [400]	train-many_logloss:0.30839	test-many_logloss:0.31178	valid-many_logloss:0.31227
# [499]	train-many_logloss:0.27036	test-many_logloss:0.27420	valid-many_logloss:0.27475
# {'alpha': 1.055992173502114e-05, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.8017715093779021, 'colsample_bytree': 0.7625111741024486, 'eta': 0.007606220882567551, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0.001053204847233351, 'lambda': 0.23316250775856961, 'max_depth': 1, 'min_child_weight': 1.9088058756735313e-07, 'objective': 'manybinary:logistic', 'subsample': 0.5239057927863935, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.68795	test-many_logloss:0.68798	valid-many_logloss:0.68797
# [200]	train-many_logloss:0.29812	test-many_logloss:0.30086	valid-many_logloss:0.29952
# [400]	train-many_logloss:0.22458	test-many_logloss:0.22771	valid-many_logloss:0.22692
# [499]	train-many_logloss:0.20489	test-many_logloss:0.20834	valid-many_logloss:0.20770
# {'alpha': 0, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.98982155285091, 'colsample_bytree': 0.8137063678634311, 'eta': 0.021437825449384364, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0, 'lambda': 0, 'max_depth': 5, 'min_child_weight': 2.5600171535202e-07, 'objective': 'manybinary:logistic', 'subsample': 0.7174114308249333, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.67472	test-many_logloss:0.67541	valid-many_logloss:0.67531
# [200]	train-many_logloss:0.03601	test-many_logloss:0.08140	valid-many_logloss:0.07992
# [400]	train-many_logloss:0.00834	test-many_logloss:0.06504	valid-many_logloss:0.06372
# [499]	train-many_logloss:0.00442	test-many_logloss:0.06403	valid-many_logloss:0.06295
# NEW BEST VALUE!
# {'alpha': 0, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.6189065258301154, 'colsample_bytree': 0.7882001782331782, 'eta': 0.003770077706590942, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0.0006381725365621713, 'lambda': 0, 'max_depth': 1, 'min_child_weight': 0.05537987461653371, 'objective': 'manybinary:logistic', 'subsample': 0.6537419349296045, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.69057	test-many_logloss:0.69059	valid-many_logloss:0.69058
# [200]	train-many_logloss:0.40097	test-many_logloss:0.40276	valid-many_logloss:0.40173
# [400]	train-many_logloss:0.30022	test-many_logloss:0.30285	valid-many_logloss:0.30151
# [499]	train-many_logloss:0.27370	test-many_logloss:0.27647	valid-many_logloss:0.27516
# {'alpha': 8.111376998577662e-05, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.8729133438901646, 'colsample_bytree': 0.5205123603280772, 'eta': 0.0309650866085196, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0, 'lambda': 7.910525070154376e-06, 'max_depth': 3, 'min_child_weight': 7.405155036744976e-05, 'objective': 'manybinary:logistic', 'subsample': 0.6231629412057431, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.66972	test-many_logloss:0.66989	valid-many_logloss:0.67000
# [200]	train-many_logloss:0.06395	test-many_logloss:0.09099	valid-many_logloss:0.08955
# [400]	train-many_logloss:0.02861	test-many_logloss:0.06842	valid-many_logloss:0.06750
# [499]	train-many_logloss:0.02050	test-many_logloss:0.06465	valid-many_logloss:0.06397
# {'alpha': 0, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.7211698432094364, 'colsample_bytree': 0.712394975511369, 'eta': 0.008477424619483462, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0, 'lambda': 0, 'max_depth': 3, 'min_child_weight': 32.756265617720345, 'objective': 'manybinary:logistic', 'subsample': 0.6995489417449295, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.68681	test-many_logloss:0.68687	valid-many_logloss:0.68689
# [200]	train-many_logloss:0.22324	test-many_logloss:0.22820	valid-many_logloss:0.22879
# [400]	train-many_logloss:0.14385	test-many_logloss:0.15034	valid-many_logloss:0.15150
# [499]	train-many_logloss:0.12996	test-many_logloss:0.13688	valid-many_logloss:0.13833
# {'alpha': 0, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.7987531851832483, 'colsample_bytree': 0.7299740823920091, 'eta': 0.06030778497723384, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0, 'lambda': 0, 'max_depth': 8, 'min_child_weight': 0.00023882505207060682, 'objective': 'manybinary:logistic', 'subsample': 0.8750385697829414, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.63870	test-many_logloss:0.64346	valid-many_logloss:0.64285
# [105]	train-many_logloss:0.00238	test-many_logloss:0.07446	valid-many_logloss:0.07487
# {'alpha': 1.3107376407541217e-06, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.7332732947918047, 'colsample_bytree': 0.5030735772414907, 'eta': 0.0015245875835189877, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 9.066632495478617e-06, 'lambda': 0, 'max_depth': 3, 'min_child_weight': 135.18110003620356, 'objective': 'manybinary:logistic', 'subsample': 0.5593100367488764, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.69212	test-many_logloss:0.69212	valid-many_logloss:0.69212
# [200]	train-many_logloss:0.53491	test-many_logloss:0.53519	valid-many_logloss:0.53523
# [400]	train-many_logloss:0.43989	test-many_logloss:0.44027	valid-many_logloss:0.44042
# [499]	train-many_logloss:0.40654	test-many_logloss:0.40701	valid-many_logloss:0.40718
# {'alpha': 0.0038647140584965353, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.7781226592895327, 'colsample_bytree': 0.6398164878102375, 'eta': 0.0041851001124752684, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 5.825640644469816e-06, 'lambda': 0, 'max_depth': 8, 'min_child_weight': 0.00537473915613328, 'objective': 'manybinary:logistic', 'subsample': 0.5391816076002862, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.68937	test-many_logloss:0.68962	valid-many_logloss:0.68961
# [200]	train-many_logloss:0.27320	test-many_logloss:0.30168	valid-many_logloss:0.30054
# [400]	train-many_logloss:0.12597	test-many_logloss:0.16746	valid-many_logloss:0.16548
# [499]	train-many_logloss:0.08830	test-many_logloss:0.13374	valid-many_logloss:0.13165
# {'alpha': 0, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.980487461508577, 'colsample_bytree': 0.872601457169579, 'eta': 0.46040749038190176, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0, 'lambda': 0, 'max_depth': 5, 'min_child_weight': 0.0003681699610575285, 'objective': 'manybinary:logistic', 'subsample': 0.7369430758094139, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.38356	test-many_logloss:0.39847	valid-many_logloss:0.39799
# [27]	train-many_logloss:0.00210	test-many_logloss:inf	valid-many_logloss:nan
# {'alpha': 4.07913722402031e-06, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.7818800515438491, 'colsample_bytree': 0.7724637498474807, 'eta': 0.008563159803242014, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 1.138875246733091, 'lambda': 0.004929740945608459, 'max_depth': 8, 'min_child_weight': 1.2189098145853323e-06, 'objective': 'manybinary:logistic', 'subsample': 0.92406704328224, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.68512	test-many_logloss:0.68575	valid-many_logloss:0.68576
# [200]	train-many_logloss:0.11229	test-many_logloss:0.15929	valid-many_logloss:0.15789
# [400]	train-many_logloss:0.03047	test-many_logloss:0.08458	valid-many_logloss:0.08385
# [499]	train-many_logloss:0.01974	test-many_logloss:0.07519	valid-many_logloss:0.07496
# {'alpha': 5.769734865019702e-05, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.947651214492775, 'colsample_bytree': 0.8633457836387857, 'eta': 0.3977029463511548, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0.003128466805888169, 'lambda': 0, 'max_depth': 6, 'min_child_weight': 23.81766245704533, 'objective': 'manybinary:logistic', 'subsample': 0.8289219023831419, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.43751	test-many_logloss:0.43986	valid-many_logloss:0.44247
# [123]	train-many_logloss:0.05417	test-many_logloss:0.09020	valid-many_logloss:0.08868
# {'alpha': 0, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.8025654416649992, 'colsample_bytree': 0.8748052006921443, 'eta': 0.009393489875683971, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0, 'lambda': 0, 'max_depth': 2, 'min_child_weight': 0.013234942416650719, 'objective': 'manybinary:logistic', 'subsample': 0.8694541664166509, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.68619	test-many_logloss:0.68622	valid-many_logloss:0.68622
# [200]	train-many_logloss:0.21970	test-many_logloss:0.22572	valid-many_logloss:0.22511
# [400]	train-many_logloss:0.14107	test-many_logloss:0.15176	valid-many_logloss:0.15049
# [499]	train-many_logloss:0.12216	test-many_logloss:0.13483	valid-many_logloss:0.13362
# {'alpha': 3.1952805148613077, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.8947364949908566, 'colsample_bytree': 0.6489201195603208, 'eta': 0.04857283281713467, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0, 'lambda': 5.599926914440914e-07, 'max_depth': 4, 'min_child_weight': 1.7794291782520545e-07, 'objective': 'manybinary:logistic', 'subsample': 0.5893278373512121, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.65612	test-many_logloss:0.65686	valid-many_logloss:0.65672
# [200]	train-many_logloss:0.04301	test-many_logloss:0.07469	valid-many_logloss:0.07336
# [400]	train-many_logloss:0.02610	test-many_logloss:0.06642	valid-many_logloss:0.06428
# [499]	train-many_logloss:0.02318	test-many_logloss:0.06543	valid-many_logloss:0.06328
# {'alpha': 4.274863989343924, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.8907813804127731, 'colsample_bytree': 0.6604066200212692, 'eta': 0.11030976568712257, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0, 'lambda': 1.4369059436000864e-07, 'max_depth': 4, 'min_child_weight': 9.018734361769693e-07, 'objective': 'manybinary:logistic', 'subsample': 0.7992982629187013, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.61067	test-many_logloss:0.61247	valid-many_logloss:0.61213
# [200]	train-many_logloss:0.02806	test-many_logloss:0.06754	valid-many_logloss:0.06655
# [336]	train-many_logloss:0.02474	test-many_logloss:0.06637	valid-many_logloss:0.06523
# {'alpha': 5.844369452841651, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.9859822310057766, 'colsample_bytree': 0.6078641072138384, 'eta': 0.024235267945627272, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0, 'lambda': 3.470291568178146e-05, 'max_depth': 4, 'min_child_weight': 1.7655884001791969e-07, 'objective': 'manybinary:logistic', 'subsample': 0.6921634932491363, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.67480	test-many_logloss:0.67506	valid-many_logloss:0.67510
# [200]	train-many_logloss:0.08580	test-many_logloss:0.10527	valid-many_logloss:0.10458
# [400]	train-many_logloss:0.05479	test-many_logloss:0.08168	valid-many_logloss:0.08067
# [499]	train-many_logloss:0.04885	test-many_logloss:0.07784	valid-many_logloss:0.07674
# {'alpha': 0.05170060610448261, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.905731104134081, 'colsample_bytree': 0.8150271638455195, 'eta': 0.14197463891222759, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0, 'lambda': 1.1666140423541139e-07, 'max_depth': 4, 'min_child_weight': 1.2985067381228998e-07, 'objective': 'manybinary:logistic', 'subsample': 0.5924492078271488, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.58473	test-many_logloss:0.58758	valid-many_logloss:0.58709
# [133]	train-many_logloss:0.00318	test-many_logloss:0.06363	valid-many_logloss:0.06421
# {'alpha': 0, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.9988898538120551, 'colsample_bytree': 0.6728392708315646, 'eta': 0.023875924465142258, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0, 'lambda': 0.059722664153949466, 'max_depth': 4, 'min_child_weight': 0.0010263229181663566, 'objective': 'manybinary:logistic', 'subsample': 0.6857243847952346, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.67378	test-many_logloss:0.67416	valid-many_logloss:0.67415
# [200]	train-many_logloss:0.05156	test-many_logloss:0.08606	valid-many_logloss:0.08436
# [400]	train-many_logloss:0.01762	test-many_logloss:0.06435	valid-many_logloss:0.06347
# [499]	train-many_logloss:0.01121	test-many_logloss:0.06137	valid-many_logloss:0.06074
# NEW BEST VALUE!
# 100%|██████████| 25/25 [19:44<00:00, 47.39s/trial, best loss: 0.060741]
# {'alpha': 0, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.7489980469009814, 'colsample_bytree': 0.9420146676089547, 'eta': 0.0070706936561268224, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0, 'lambda': 0, 'max_depth': 5, 'min_child_weight': 2.1041667775099838e-05, 'objective': 'manybinary:logistic', 'subsample': 0.6262451727083667, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.68710	test-many_logloss:0.68730	valid-many_logloss:0.68731
# [200]	train-many_logloss:0.17781	test-many_logloss:0.20148	valid-many_logloss:0.20419
# [400]	train-many_logloss:0.06736	test-many_logloss:0.10216	valid-many_logloss:0.10739
# [499]	train-many_logloss:0.04553	test-many_logloss:0.08393	valid-many_logloss:0.09016
# NEW BEST VALUE!
# {'alpha': 0, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.8357246683355697, 'colsample_bytree': 0.7491187395188089, 'eta': 0.605518780660455, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0, 'lambda': 0, 'max_depth': 5, 'min_child_weight': 118.844312919608, 'objective': 'manybinary:logistic', 'subsample': 0.6525233714163394, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.39971	test-many_logloss:0.40128	valid-many_logloss:0.40161
# [94]	train-many_logloss:0.26132	test-many_logloss:0.26213	valid-many_logloss:0.26365
# {'alpha': 3.7815423151500604e-05, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.5547269545129563, 'colsample_bytree': 0.9843635186756493, 'eta': 0.5949933323999959, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0.00013347887526644314, 'lambda': 0, 'max_depth': 9, 'min_child_weight': 7.283920920982167e-06, 'objective': 'manybinary:logistic', 'subsample': 0.9927469091208938, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.28047	test-many_logloss:0.32903	valid-many_logloss:0.33307
# [27]	train-many_logloss:0.00000	test-many_logloss:0.11849	valid-many_logloss:0.14220
# {'alpha': 0.003403374940376167, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.6367989155272455, 'colsample_bytree': 0.6974194337846622, 'eta': 0.3029677824305006, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 1.5812851156161036, 'lambda': 1.2783614674881826e-06, 'max_depth': 5, 'min_child_weight': 2.558034001077105, 'objective': 'manybinary:logistic', 'subsample': 0.7481581307597385, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.47671	test-many_logloss:0.48164	valid-many_logloss:0.48218
# [107]	train-many_logloss:0.01089	test-many_logloss:0.06218	valid-many_logloss:0.06927
# NEW BEST VALUE!
# {'alpha': 0, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.822829897275416, 'colsample_bytree': 0.8661025998484644, 'eta': 0.011434936316016709, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0, 'lambda': 2.091554134375915, 'max_depth': 8, 'min_child_weight': 1.6723514459697203e-05, 'objective': 'manybinary:logistic', 'subsample': 0.6325684178842439, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.68346	test-many_logloss:0.68385	valid-many_logloss:0.68380
# [200]	train-many_logloss:0.09507	test-many_logloss:0.12765	valid-many_logloss:0.13202
# [400]	train-many_logloss:0.02927	test-many_logloss:0.07209	valid-many_logloss:0.07897
# [499]	train-many_logloss:0.01960	test-many_logloss:0.06517	valid-many_logloss:0.07250
# {'alpha': 0, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.9439090074967231, 'colsample_bytree': 0.5525925639927433, 'eta': 0.0009915520889927426, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0, 'lambda': 0.004073992634408555, 'max_depth': 2, 'min_child_weight': 1.3633143522854873e-06, 'objective': 'manybinary:logistic', 'subsample': 0.9311207654760087, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.69241	test-many_logloss:0.69242	valid-many_logloss:0.69242
# [200]	train-many_logloss:0.56880	test-many_logloss:0.56994	valid-many_logloss:0.56973
# [400]	train-many_logloss:0.47978	test-many_logloss:0.48179	valid-many_logloss:0.48157
# [499]	train-many_logloss:0.44448	test-many_logloss:0.44692	valid-many_logloss:0.44671
# {'alpha': 0, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.787125082065971, 'colsample_bytree': 0.5243474561426513, 'eta': 0.8099003407203538, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 7.475715249737038e-05, 'lambda': 0.0003639646509775927, 'max_depth': 7, 'min_child_weight': 0.09759627970810976, 'objective': 'manybinary:logistic', 'subsample': 0.553442319017114, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.24943	test-many_logloss:0.28692	valid-many_logloss:0.28708
# [22]	train-many_logloss:nan	test-many_logloss:nan	valid-many_logloss:nan
# {'alpha': 0, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.7061150549075759, 'colsample_bytree': 0.5843009197915733, 'eta': 0.002630107568123181, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 6.947115616562489, 'lambda': 0, 'max_depth': 10, 'min_child_weight': 41.36978142254861, 'objective': 'manybinary:logistic', 'subsample': 0.7453409993563878, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.69117	test-many_logloss:0.69119	valid-many_logloss:0.69119
# [200]	train-many_logloss:0.43010	test-many_logloss:0.43270	valid-many_logloss:0.43252
# [400]	train-many_logloss:0.30429	test-many_logloss:0.30862	valid-many_logloss:0.30884
# [499]	train-many_logloss:0.26541	test-many_logloss:0.27034	valid-many_logloss:0.27089
# {'alpha': 1.055992173502114e-05, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.8017715093779021, 'colsample_bytree': 0.7625111741024486, 'eta': 0.007606220882567551, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0.001053204847233351, 'lambda': 0.23316250775856961, 'max_depth': 1, 'min_child_weight': 1.9088058756735313e-07, 'objective': 'manybinary:logistic', 'subsample': 0.5239057927863935, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.68794	test-many_logloss:0.68799	valid-many_logloss:0.68798
# [200]	train-many_logloss:0.29603	test-many_logloss:0.29996	valid-many_logloss:0.29957
# [400]	train-many_logloss:0.22071	test-many_logloss:0.22602	valid-many_logloss:0.22638
# [499]	train-many_logloss:0.20046	test-many_logloss:0.20624	valid-many_logloss:0.20689
# {'alpha': 0, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.98982155285091, 'colsample_bytree': 0.8137063678634311, 'eta': 0.021437825449384364, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0, 'lambda': 0, 'max_depth': 5, 'min_child_weight': 2.5600171535202e-07, 'objective': 'manybinary:logistic', 'subsample': 0.7174114308249333, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.67476	test-many_logloss:0.67535	valid-many_logloss:0.67546
# [200]	train-many_logloss:0.03012	test-many_logloss:0.07395	valid-many_logloss:0.08038
# [400]	train-many_logloss:0.00566	test-many_logloss:0.05812	valid-many_logloss:0.06724
# [488]	train-many_logloss:0.00293	test-many_logloss:0.05710	valid-many_logloss:0.06707
# NEW BEST VALUE!
# {'alpha': 0, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.6189065258301154, 'colsample_bytree': 0.7882001782331782, 'eta': 0.003770077706590942, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0.0006381725365621713, 'lambda': 0, 'max_depth': 1, 'min_child_weight': 0.05537987461653371, 'objective': 'manybinary:logistic', 'subsample': 0.6537419349296045, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.69059	test-many_logloss:0.69061	valid-many_logloss:0.69061
# [200]	train-many_logloss:0.39995	test-many_logloss:0.40223	valid-many_logloss:0.40189
# [400]	train-many_logloss:0.29816	test-many_logloss:0.30187	valid-many_logloss:0.30158
# [499]	train-many_logloss:0.27114	test-many_logloss:0.27544	valid-many_logloss:0.27521
# {'alpha': 8.111376998577662e-05, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.8729133438901646, 'colsample_bytree': 0.5205123603280772, 'eta': 0.0309650866085196, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0, 'lambda': 7.910525070154376e-06, 'max_depth': 3, 'min_child_weight': 7.405155036744976e-05, 'objective': 'manybinary:logistic', 'subsample': 0.6231629412057431, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.66959	test-many_logloss:0.66992	valid-many_logloss:0.66982
# [200]	train-many_logloss:0.05584	test-many_logloss:0.08255	valid-many_logloss:0.08871
# [400]	train-many_logloss:0.02185	test-many_logloss:0.05978	valid-many_logloss:0.06859
# [499]	train-many_logloss:0.01473	test-many_logloss:0.05550	valid-many_logloss:0.06535
# NEW BEST VALUE!
# {'alpha': 0, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.7211698432094364, 'colsample_bytree': 0.712394975511369, 'eta': 0.008477424619483462, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0, 'lambda': 0, 'max_depth': 3, 'min_child_weight': 32.756265617720345, 'objective': 'manybinary:logistic', 'subsample': 0.6995489417449295, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.68682	test-many_logloss:0.68683	valid-many_logloss:0.68683
# [200]	train-many_logloss:0.21730	test-many_logloss:0.22338	valid-many_logloss:0.22478
# [400]	train-many_logloss:0.13605	test-many_logloss:0.14460	valid-many_logloss:0.14837
# [499]	train-many_logloss:0.12219	test-many_logloss:0.13161	valid-many_logloss:0.13626
# {'alpha': 0, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.7987531851832483, 'colsample_bytree': 0.7299740823920091, 'eta': 0.06030778497723384, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0, 'lambda': 0, 'max_depth': 8, 'min_child_weight': 0.00023882505207060682, 'objective': 'manybinary:logistic', 'subsample': 0.8750385697829414, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.63850	test-many_logloss:0.64227	valid-many_logloss:0.64253
# [95]	train-many_logloss:0.00278	test-many_logloss:0.06771	valid-many_logloss:0.07660
# {'alpha': 1.3107376407541217e-06, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.7332732947918047, 'colsample_bytree': 0.5030735772414907, 'eta': 0.0015245875835189877, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 9.066632495478617e-06, 'lambda': 0, 'max_depth': 3, 'min_child_weight': 135.18110003620356, 'objective': 'manybinary:logistic', 'subsample': 0.5593100367488764, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.69212	test-many_logloss:0.69212	valid-many_logloss:0.69212
# [200]	train-many_logloss:0.53448	test-many_logloss:0.53508	valid-many_logloss:0.53493
# [400]	train-many_logloss:0.43902	test-many_logloss:0.44002	valid-many_logloss:0.43986
# [499]	train-many_logloss:0.40542	test-many_logloss:0.40666	valid-many_logloss:0.40646
# {'alpha': 0.0038647140584965353, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.7781226592895327, 'colsample_bytree': 0.6398164878102375, 'eta': 0.0041851001124752684, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 5.825640644469816e-06, 'lambda': 0, 'max_depth': 8, 'min_child_weight': 0.00537473915613328, 'objective': 'manybinary:logistic', 'subsample': 0.5391816076002862, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.68935	test-many_logloss:0.68959	valid-many_logloss:0.68960
# [200]	train-many_logloss:0.26844	test-many_logloss:0.29650	valid-many_logloss:0.29840
# [400]	train-many_logloss:0.12114	test-many_logloss:0.16073	valid-many_logloss:0.16379
# [499]	train-many_logloss:0.08391	test-many_logloss:0.12687	valid-many_logloss:0.13060
# {'alpha': 0, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.980487461508577, 'colsample_bytree': 0.872601457169579, 'eta': 0.46040749038190176, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0, 'lambda': 0, 'max_depth': 5, 'min_child_weight': 0.0003681699610575285, 'objective': 'manybinary:logistic', 'subsample': 0.7369430758094139, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.38366	test-many_logloss:0.39730	valid-many_logloss:0.39855
# [37]	train-many_logloss:0.00025	test-many_logloss:0.07852	valid-many_logloss:0.09465
# {'alpha': 4.07913722402031e-06, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.7818800515438491, 'colsample_bytree': 0.7724637498474807, 'eta': 0.008563159803242014, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 1.138875246733091, 'lambda': 0.004929740945608459, 'max_depth': 8, 'min_child_weight': 1.2189098145853323e-06, 'objective': 'manybinary:logistic', 'subsample': 0.92406704328224, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.68513	test-many_logloss:0.68571	valid-many_logloss:0.68578
# [200]	train-many_logloss:0.10860	test-many_logloss:0.15261	valid-many_logloss:0.15592
# [400]	train-many_logloss:0.02785	test-many_logloss:0.07812	valid-many_logloss:0.08377
# [499]	train-many_logloss:0.01752	test-many_logloss:0.06934	valid-many_logloss:0.07594
# {'alpha': 5.769734865019702e-05, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.947651214492775, 'colsample_bytree': 0.8633457836387857, 'eta': 0.3977029463511548, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0.003128466805888169, 'lambda': 0, 'max_depth': 6, 'min_child_weight': 23.81766245704533, 'objective': 'manybinary:logistic', 'subsample': 0.8289219023831419, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.43655	test-many_logloss:0.43987	valid-many_logloss:0.44011
# [85]	train-many_logloss:0.05357	test-many_logloss:0.08360	valid-many_logloss:0.09338
# {'alpha': 0, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.8025654416649992, 'colsample_bytree': 0.8748052006921443, 'eta': 0.009393489875683971, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0, 'lambda': 0, 'max_depth': 2, 'min_child_weight': 0.013234942416650719, 'objective': 'manybinary:logistic', 'subsample': 0.8694541664166509, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.68622	test-many_logloss:0.68629	valid-many_logloss:0.68628
# [200]	train-many_logloss:0.21552	test-many_logloss:0.22237	valid-many_logloss:0.22312
# [400]	train-many_logloss:0.13534	test-many_logloss:0.14675	valid-many_logloss:0.14944
# [499]	train-many_logloss:0.11561	test-many_logloss:0.12917	valid-many_logloss:0.13244
# {'alpha': 3.1952805148613077, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.8947364949908566, 'colsample_bytree': 0.6489201195603208, 'eta': 0.04857283281713467, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0, 'lambda': 5.599926914440914e-07, 'max_depth': 4, 'min_child_weight': 1.7794291782520545e-07, 'objective': 'manybinary:logistic', 'subsample': 0.5893278373512121, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.65606	test-many_logloss:0.65668	valid-many_logloss:0.65658
# [200]	train-many_logloss:0.03653	test-many_logloss:0.06706	valid-many_logloss:0.07438
# [400]	train-many_logloss:0.02212	test-many_logloss:0.05938	valid-many_logloss:0.06750
# [499]	train-many_logloss:0.01997	test-many_logloss:0.05843	valid-many_logloss:0.06683
# {'alpha': 3.002743880356697, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.880750740505001, 'colsample_bytree': 0.6378931895802679, 'eta': 0.07394609656696631, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0, 'lambda': 2.007018003013685e-07, 'max_depth': 4, 'min_child_weight': 0.00020723760317545867, 'objective': 'manybinary:logistic', 'subsample': 0.7957161829611085, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.63634	test-many_logloss:0.63711	valid-many_logloss:0.63721
# [200]	train-many_logloss:0.02168	test-many_logloss:0.06020	valid-many_logloss:0.06759
# [400]	train-many_logloss:0.01599	test-many_logloss:0.05749	valid-many_logloss:0.06559
# [407]	train-many_logloss:0.01593	test-many_logloss:0.05747	valid-many_logloss:0.06558
# {'alpha': 1.200782835459218, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.8687918622527812, 'colsample_bytree': 0.6034148520201185, 'eta': 0.19484734134839077, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0, 'lambda': 1.635393836955409e-05, 'max_depth': 4, 'min_child_weight': 0.0005216471023949306, 'objective': 'manybinary:logistic', 'subsample': 0.7985877624194806, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.55122	test-many_logloss:0.55528	valid-many_logloss:0.55407
# [136]	train-many_logloss:0.00676	test-many_logloss:0.05449	valid-many_logloss:0.06438
# NEW BEST VALUE!
# {'alpha': 0.1617477004218055, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.8795500918776347, 'colsample_bytree': 0.5859910845876186, 'eta': 0.14667519751803157, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0, 'lambda': 2.9500083341754825e-05, 'max_depth': 4, 'min_child_weight': 0.0009389341266388139, 'objective': 'manybinary:logistic', 'subsample': 0.8003293840357051, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.58249	test-many_logloss:0.58535	valid-many_logloss:0.58483
# [128]	train-many_logloss:0.00269	test-many_logloss:0.05410	valid-many_logloss:0.06300
# NEW BEST VALUE!
# {'alpha': 0.12561116777862372, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.9216433346782474, 'colsample_bytree': 0.5937783882219659, 'eta': 0.16342277038913713, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0, 'lambda': 0.00018094967392993672, 'max_depth': 4, 'min_child_weight': 0.001601165143421856, 'objective': 'manybinary:logistic', 'subsample': 0.799112137913945, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.57075	test-many_logloss:0.57434	valid-many_logloss:0.57361
# [118]	train-many_logloss:0.00226	test-many_logloss:0.05657	valid-many_logloss:0.06432
# 100%|██████████| 25/25 [18:17<00:00, 43.89s/trial, best loss: 0.062533]
# {'alpha': 0, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.7489980469009814, 'colsample_bytree': 0.9420146676089547, 'eta': 0.0070706936561268224, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0, 'lambda': 0, 'max_depth': 5, 'min_child_weight': 2.1041667775099838e-05, 'objective': 'manybinary:logistic', 'subsample': 0.6262451727083667, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.68702	test-many_logloss:0.68726	valid-many_logloss:0.68726
# [200]	train-many_logloss:0.17886	test-many_logloss:0.20364	valid-many_logloss:0.20464
# [400]	train-many_logloss:0.06805	test-many_logloss:0.10452	valid-many_logloss:0.10619
# [499]	train-many_logloss:0.04623	test-many_logloss:0.08665	valid-many_logloss:0.08843
# NEW BEST VALUE!
# {'alpha': 0, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.8357246683355697, 'colsample_bytree': 0.7491187395188089, 'eta': 0.605518780660455, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0, 'lambda': 0, 'max_depth': 5, 'min_child_weight': 118.844312919608, 'objective': 'manybinary:logistic', 'subsample': 0.6525233714163394, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.39963	test-many_logloss:0.39968	valid-many_logloss:0.39938
# [38]	train-many_logloss:0.25665	test-many_logloss:0.25901	valid-many_logloss:0.25807
# {'alpha': 3.7815423151500604e-05, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.5547269545129563, 'colsample_bytree': 0.9843635186756493, 'eta': 0.5949933323999959, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0.00013347887526644314, 'lambda': 0, 'max_depth': 9, 'min_child_weight': 7.283920920982167e-06, 'objective': 'manybinary:logistic', 'subsample': 0.9927469091208938, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.28326	test-many_logloss:0.33076	valid-many_logloss:0.33167
# [27]	train-many_logloss:0.00000	test-many_logloss:0.13373	valid-many_logloss:0.14388
# {'alpha': 0.003403374940376167, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.6367989155272455, 'colsample_bytree': 0.6974194337846622, 'eta': 0.3029677824305006, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 1.5812851156161036, 'lambda': 1.2783614674881826e-06, 'max_depth': 5, 'min_child_weight': 2.558034001077105, 'objective': 'manybinary:logistic', 'subsample': 0.7481581307597385, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.47423	test-many_logloss:0.48058	valid-many_logloss:0.47959
# [172]	train-many_logloss:0.01001	test-many_logloss:0.06525	valid-many_logloss:0.06307
# NEW BEST VALUE!
# {'alpha': 0, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.822829897275416, 'colsample_bytree': 0.8661025998484644, 'eta': 0.011434936316016709, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0, 'lambda': 2.091554134375915, 'max_depth': 8, 'min_child_weight': 1.6723514459697203e-05, 'objective': 'manybinary:logistic', 'subsample': 0.6325684178842439, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.68344	test-many_logloss:0.68383	valid-many_logloss:0.68382
# [200]	train-many_logloss:0.09578	test-many_logloss:0.13004	valid-many_logloss:0.13112
# [400]	train-many_logloss:0.02978	test-many_logloss:0.07501	valid-many_logloss:0.07698
# [499]	train-many_logloss:0.02005	test-many_logloss:0.06808	valid-many_logloss:0.07031
# {'alpha': 0, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.9439090074967231, 'colsample_bytree': 0.5525925639927433, 'eta': 0.0009915520889927426, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0, 'lambda': 0.004073992634408555, 'max_depth': 2, 'min_child_weight': 1.3633143522854873e-06, 'objective': 'manybinary:logistic', 'subsample': 0.9311207654760087, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.69242	test-many_logloss:0.69242	valid-many_logloss:0.69242
# [200]	train-many_logloss:0.56953	test-many_logloss:0.57082	valid-many_logloss:0.57061
# [400]	train-many_logloss:0.48080	test-many_logloss:0.48323	valid-many_logloss:0.48285
# [499]	train-many_logloss:0.44561	test-many_logloss:0.44855	valid-many_logloss:0.44813
# {'alpha': 0, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.787125082065971, 'colsample_bytree': 0.5243474561426513, 'eta': 0.8099003407203538, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 7.475715249737038e-05, 'lambda': 0.0003639646509775927, 'max_depth': 7, 'min_child_weight': 0.09759627970810976, 'objective': 'manybinary:logistic', 'subsample': 0.553442319017114, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.24354	test-many_logloss:0.28816	valid-many_logloss:0.28382
# [23]	train-many_logloss:nan	test-many_logloss:nan	valid-many_logloss:nan
# {'alpha': 0, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.7061150549075759, 'colsample_bytree': 0.5843009197915733, 'eta': 0.002630107568123181, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 6.947115616562489, 'lambda': 0, 'max_depth': 10, 'min_child_weight': 41.36978142254861, 'objective': 'manybinary:logistic', 'subsample': 0.7453409993563878, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.69117	test-many_logloss:0.69120	valid-many_logloss:0.69119
# [200]	train-many_logloss:0.42992	test-many_logloss:0.43260	valid-many_logloss:0.43205
# [400]	train-many_logloss:0.30440	test-many_logloss:0.30856	valid-many_logloss:0.30821
# [499]	train-many_logloss:0.26552	test-many_logloss:0.27020	valid-many_logloss:0.27003
# {'alpha': 1.055992173502114e-05, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.8017715093779021, 'colsample_bytree': 0.7625111741024486, 'eta': 0.007606220882567551, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0.001053204847233351, 'lambda': 0.23316250775856961, 'max_depth': 1, 'min_child_weight': 1.9088058756735313e-07, 'objective': 'manybinary:logistic', 'subsample': 0.5239057927863935, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.68795	test-many_logloss:0.68798	valid-many_logloss:0.68797
# [200]	train-many_logloss:0.29639	test-many_logloss:0.30012	valid-many_logloss:0.29893
# [400]	train-many_logloss:0.22036	test-many_logloss:0.22572	valid-many_logloss:0.22462
# [499]	train-many_logloss:0.19979	test-many_logloss:0.20571	valid-many_logloss:0.20484
# {'alpha': 0, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.98982155285091, 'colsample_bytree': 0.8137063678634311, 'eta': 0.021437825449384364, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0, 'lambda': 0, 'max_depth': 5, 'min_child_weight': 2.5600171535202e-07, 'objective': 'manybinary:logistic', 'subsample': 0.7174114308249333, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.67469	test-many_logloss:0.67541	valid-many_logloss:0.67538
# [200]	train-many_logloss:0.03059	test-many_logloss:0.07664	valid-many_logloss:0.07782
# [400]	train-many_logloss:0.00586	test-many_logloss:0.06307	valid-many_logloss:0.06363
# [469]	train-many_logloss:0.00354	test-many_logloss:0.06299	valid-many_logloss:0.06335
# {'alpha': 0, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.6189065258301154, 'colsample_bytree': 0.7882001782331782, 'eta': 0.003770077706590942, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0.0006381725365621713, 'lambda': 0, 'max_depth': 1, 'min_child_weight': 0.05537987461653371, 'objective': 'manybinary:logistic', 'subsample': 0.6537419349296045, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.69056	test-many_logloss:0.69057	valid-many_logloss:0.69057
# [200]	train-many_logloss:0.40030	test-many_logloss:0.40258	valid-many_logloss:0.40165
# [400]	train-many_logloss:0.29850	test-many_logloss:0.30224	valid-many_logloss:0.30099
# [499]	train-many_logloss:0.27141	test-many_logloss:0.27565	valid-many_logloss:0.27441
# {'alpha': 8.111376998577662e-05, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.8729133438901646, 'colsample_bytree': 0.5205123603280772, 'eta': 0.0309650866085196, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0, 'lambda': 7.910525070154376e-06, 'max_depth': 3, 'min_child_weight': 7.405155036744976e-05, 'objective': 'manybinary:logistic', 'subsample': 0.6231629412057431, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.66952	test-many_logloss:0.66966	valid-many_logloss:0.66980
# [200]	train-many_logloss:0.05600	test-many_logloss:0.08445	valid-many_logloss:0.08571
# [400]	train-many_logloss:0.02246	test-many_logloss:0.06403	valid-many_logloss:0.06420
# [499]	train-many_logloss:0.01536	test-many_logloss:0.06136	valid-many_logloss:0.06078
# NEW BEST VALUE!
# {'alpha': 0, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.7211698432094364, 'colsample_bytree': 0.712394975511369, 'eta': 0.008477424619483462, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0, 'lambda': 0, 'max_depth': 3, 'min_child_weight': 32.756265617720345, 'objective': 'manybinary:logistic', 'subsample': 0.6995489417449295, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.68677	test-many_logloss:0.68684	valid-many_logloss:0.68683
# [200]	train-many_logloss:0.21673	test-many_logloss:0.22332	valid-many_logloss:0.22328
# [400]	train-many_logloss:0.13698	test-many_logloss:0.14604	valid-many_logloss:0.14707
# [499]	train-many_logloss:0.12335	test-many_logloss:0.13337	valid-many_logloss:0.13454
# {'alpha': 0, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.7987531851832483, 'colsample_bytree': 0.7299740823920091, 'eta': 0.06030778497723384, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0, 'lambda': 0, 'max_depth': 8, 'min_child_weight': 0.00023882505207060682, 'objective': 'manybinary:logistic', 'subsample': 0.8750385697829414, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.63824	test-many_logloss:0.64237	valid-many_logloss:0.64243
# [102]	train-many_logloss:0.00204	test-many_logloss:0.07222	valid-many_logloss:0.07619
# {'alpha': 1.3107376407541217e-06, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.7332732947918047, 'colsample_bytree': 0.5030735772414907, 'eta': 0.0015245875835189877, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 9.066632495478617e-06, 'lambda': 0, 'max_depth': 3, 'min_child_weight': 135.18110003620356, 'objective': 'manybinary:logistic', 'subsample': 0.5593100367488764, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.69212	test-many_logloss:0.69212	valid-many_logloss:0.69212
# [200]	train-many_logloss:0.53468	test-many_logloss:0.53498	valid-many_logloss:0.53495
# [400]	train-many_logloss:0.43915	test-many_logloss:0.43974	valid-many_logloss:0.43962
# [499]	train-many_logloss:0.40553	test-many_logloss:0.40624	valid-many_logloss:0.40608
# {'alpha': 0.0038647140584965353, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.7781226592895327, 'colsample_bytree': 0.6398164878102375, 'eta': 0.0041851001124752684, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 5.825640644469816e-06, 'lambda': 0, 'max_depth': 8, 'min_child_weight': 0.00537473915613328, 'objective': 'manybinary:logistic', 'subsample': 0.5391816076002862, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.68932	test-many_logloss:0.68958	valid-many_logloss:0.68954
# [200]	train-many_logloss:0.26903	test-many_logloss:0.29780	valid-many_logloss:0.29848
# [400]	train-many_logloss:0.12163	test-many_logloss:0.16213	valid-many_logloss:0.16351
# [499]	train-many_logloss:0.08429	test-many_logloss:0.12841	valid-many_logloss:0.12991
# {'alpha': 0, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.980487461508577, 'colsample_bytree': 0.872601457169579, 'eta': 0.46040749038190176, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0, 'lambda': 0, 'max_depth': 5, 'min_child_weight': 0.0003681699610575285, 'objective': 'manybinary:logistic', 'subsample': 0.7369430758094139, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.38222	test-many_logloss:0.39869	valid-many_logloss:0.39703
# [30]	train-many_logloss:0.00080	test-many_logloss:0.08733	valid-many_logloss:nan
# ...
# [0]	train-many_logloss:0.47695	test-many_logloss:0.48097	valid-many_logloss:0.48157
# [87]	train-many_logloss:0.01150	test-many_logloss:0.06594	valid-many_logloss:0.06663
# NEW BEST VALUE!
# {'alpha': 0, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.822829897275416, 'colsample_bytree': 0.8661025998484644, 'eta': 0.011434936316016709, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0, 'lambda': 2.091554134375915, 'max_depth': 8, 'min_child_weight': 1.6723514459697203e-05, 'objective': 'manybinary:logistic', 'subsample': 0.6325684178842439, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.68351	test-many_logloss:0.68383	valid-many_logloss:0.68388
# [200]	train-many_logloss:0.09770	test-many_logloss:0.12980	valid-many_logloss:0.13242
# [400]	train-many_logloss:0.03094	test-many_logloss:0.07642	valid-many_logloss:0.07778
# [499]	train-many_logloss:0.02098	test-many_logloss:0.07003	valid-many_logloss:0.07107
# {'alpha': 0, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.9439090074967231, 'colsample_bytree': 0.5525925639927433, 'eta': 0.0009915520889927426, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0, 'lambda': 0.004073992634408555, 'max_depth': 2, 'min_child_weight': 1.3633143522854873e-06, 'objective': 'manybinary:logistic', 'subsample': 0.9311207654760087, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.69241	test-many_logloss:0.69241	valid-many_logloss:0.69241
# [200]	train-many_logloss:0.56911	test-many_logloss:0.56976	valid-many_logloss:0.57011
# [400]	train-many_logloss:0.47997	test-many_logloss:0.48129	valid-many_logloss:0.48190
# [499]	train-many_logloss:0.44470	test-many_logloss:0.44630	valid-many_logloss:0.44704
# {'alpha': 0, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.787125082065971, 'colsample_bytree': 0.5243474561426513, 'eta': 0.8099003407203538, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 7.475715249737038e-05, 'lambda': 0.0003639646509775927, 'max_depth': 7, 'min_child_weight': 0.09759627970810976, 'objective': 'manybinary:logistic', 'subsample': 0.553442319017114, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.25010	test-many_logloss:0.28335	valid-many_logloss:0.29142
# [21]	train-many_logloss:nan	test-many_logloss:nan	valid-many_logloss:nan
# {'alpha': 0, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.7061150549075759, 'colsample_bytree': 0.5843009197915733, 'eta': 0.002630107568123181, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 6.947115616562489, 'lambda': 0, 'max_depth': 10, 'min_child_weight': 41.36978142254861, 'objective': 'manybinary:logistic', 'subsample': 0.7453409993563878, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.69119	test-many_logloss:0.69120	valid-many_logloss:0.69120
# [200]	train-many_logloss:0.43035	test-many_logloss:0.43164	valid-many_logloss:0.43280
# [400]	train-many_logloss:0.30504	test-many_logloss:0.30726	valid-many_logloss:0.30944
# [499]	train-many_logloss:0.26637	test-many_logloss:0.26895	valid-many_logloss:0.27158
# {'alpha': 1.055992173502114e-05, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.8017715093779021, 'colsample_bytree': 0.7625111741024486, 'eta': 0.007606220882567551, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0.001053204847233351, 'lambda': 0.23316250775856961, 'max_depth': 1, 'min_child_weight': 1.9088058756735313e-07, 'objective': 'manybinary:logistic', 'subsample': 0.5239057927863935, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.68792	test-many_logloss:0.68793	valid-many_logloss:0.68795
# [200]	train-many_logloss:0.29484	test-many_logloss:0.29578	valid-many_logloss:0.29790
# [400]	train-many_logloss:0.21848	test-many_logloss:0.22030	valid-many_logloss:0.22325
# [499]	train-many_logloss:0.19801	test-many_logloss:0.20041	valid-many_logloss:0.20344
# {'alpha': 0, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.98982155285091, 'colsample_bytree': 0.8137063678634311, 'eta': 0.021437825449384364, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0, 'lambda': 0, 'max_depth': 5, 'min_child_weight': 2.5600171535202e-07, 'objective': 'manybinary:logistic', 'subsample': 0.7174114308249333, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.67468	test-many_logloss:0.67528	valid-many_logloss:0.67542
# [200]	train-many_logloss:0.03248	test-many_logloss:0.07832	valid-many_logloss:0.07956
# [400]	train-many_logloss:0.00660	test-many_logloss:0.06477	valid-many_logloss:0.06455
# [498]	train-many_logloss:0.00326	test-many_logloss:0.06470	valid-many_logloss:0.06413
# NEW BEST VALUE!
# {'alpha': 0, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.6189065258301154, 'colsample_bytree': 0.7882001782331782, 'eta': 0.003770077706590942, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0.0006381725365621713, 'lambda': 0, 'max_depth': 1, 'min_child_weight': 0.05537987461653371, 'objective': 'manybinary:logistic', 'subsample': 0.6537419349296045, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.69055	test-many_logloss:0.69055	valid-many_logloss:0.69056
# [200]	train-many_logloss:0.39936	test-many_logloss:0.39986	valid-many_logloss:0.40100
# [400]	train-many_logloss:0.29691	test-many_logloss:0.29773	valid-many_logloss:0.29980
# [499]	train-many_logloss:0.26961	test-many_logloss:0.27072	valid-many_logloss:0.27308
# {'alpha': 8.111376998577662e-05, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.8729133438901646, 'colsample_bytree': 0.5205123603280772, 'eta': 0.0309650866085196, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0, 'lambda': 7.910525070154376e-06, 'max_depth': 3, 'min_child_weight': 7.405155036744976e-05, 'objective': 'manybinary:logistic', 'subsample': 0.6231629412057431, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.66914	test-many_logloss:0.66934	valid-many_logloss:0.66945
# [200]	train-many_logloss:0.05921	test-many_logloss:0.08637	valid-many_logloss:0.08790
# [400]	train-many_logloss:0.02441	test-many_logloss:0.06662	valid-many_logloss:0.06690
# [499]	train-many_logloss:0.01676	test-many_logloss:0.06319	valid-many_logloss:0.06329
# NEW BEST VALUE!
# {'alpha': 0, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.7211698432094364, 'colsample_bytree': 0.712394975511369, 'eta': 0.008477424619483462, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0, 'lambda': 0, 'max_depth': 3, 'min_child_weight': 32.756265617720345, 'objective': 'manybinary:logistic', 'subsample': 0.6995489417449295, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.68678	test-many_logloss:0.68681	valid-many_logloss:0.68685
# [200]	train-many_logloss:0.21759	test-many_logloss:0.22150	valid-many_logloss:0.22435
# [400]	train-many_logloss:0.13906	test-many_logloss:0.14611	valid-many_logloss:0.14922
# [499]	train-many_logloss:0.12550	test-many_logloss:0.13376	valid-many_logloss:0.13677
# {'alpha': 0, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.7987531851832483, 'colsample_bytree': 0.7299740823920091, 'eta': 0.06030778497723384, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0, 'lambda': 0, 'max_depth': 8, 'min_child_weight': 0.00023882505207060682, 'objective': 'manybinary:logistic', 'subsample': 0.8750385697829414, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.63824	test-many_logloss:0.64244	valid-many_logloss:0.64242
# [100]	train-many_logloss:0.00233	test-many_logloss:0.07662	valid-many_logloss:0.07675
# {'alpha': 1.3107376407541217e-06, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.7332732947918047, 'colsample_bytree': 0.5030735772414907, 'eta': 0.0015245875835189877, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 9.066632495478617e-06, 'lambda': 0, 'max_depth': 3, 'min_child_weight': 135.18110003620356, 'objective': 'manybinary:logistic', 'subsample': 0.5593100367488764, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.69212	test-many_logloss:0.69212	valid-many_logloss:0.69212
# [200]	train-many_logloss:0.53436	test-many_logloss:0.53406	valid-many_logloss:0.53449
# [400]	train-many_logloss:0.43876	test-many_logloss:0.43836	valid-many_logloss:0.43913
# [499]	train-many_logloss:0.40509	test-many_logloss:0.40470	valid-many_logloss:0.40560
# {'alpha': 0.0038647140584965353, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.7781226592895327, 'colsample_bytree': 0.6398164878102375, 'eta': 0.0041851001124752684, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 5.825640644469816e-06, 'lambda': 0, 'max_depth': 8, 'min_child_weight': 0.00537473915613328, 'objective': 'manybinary:logistic', 'subsample': 0.5391816076002862, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.68937	test-many_logloss:0.68956	valid-many_logloss:0.68961
# [200]	train-many_logloss:0.27019	test-many_logloss:0.29675	valid-many_logloss:0.29861
# [400]	train-many_logloss:0.12279	test-many_logloss:0.16170	valid-many_logloss:0.16405
# [499]	train-many_logloss:0.08536	test-many_logloss:0.12836	valid-many_logloss:0.13066
# {'alpha': 0, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.980487461508577, 'colsample_bytree': 0.872601457169579, 'eta': 0.46040749038190176, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0, 'lambda': 0, 'max_depth': 5, 'min_child_weight': 0.0003681699610575285, 'objective': 'manybinary:logistic', 'subsample': 0.7369430758094139, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.38422	test-many_logloss:0.39631	valid-many_logloss:0.39897
# [31]	train-many_logloss:0.00089	test-many_logloss:0.09010	valid-many_logloss:inf
# {'alpha': 4.07913722402031e-06, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.7818800515438491, 'colsample_bytree': 0.7724637498474807, 'eta': 0.008563159803242014, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 1.138875246733091, 'lambda': 0.004929740945608459, 'max_depth': 8, 'min_child_weight': 1.2189098145853323e-06, 'objective': 'manybinary:logistic', 'subsample': 0.92406704328224, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.68509	test-many_logloss:0.68569	valid-many_logloss:0.68575
# [200]	train-many_logloss:0.11026	test-many_logloss:0.15431	valid-many_logloss:0.15662
# [400]	train-many_logloss:0.02880	test-many_logloss:0.08157	valid-many_logloss:0.08360
# [499]	train-many_logloss:0.01829	test-many_logloss:0.07323	valid-many_logloss:0.07521
# {'alpha': 5.769734865019702e-05, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.947651214492775, 'colsample_bytree': 0.8633457836387857, 'eta': 0.3977029463511548, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0.003128466805888169, 'lambda': 0, 'max_depth': 6, 'min_child_weight': 23.81766245704533, 'objective': 'manybinary:logistic', 'subsample': 0.8289219023831419, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.43589	test-many_logloss:0.43902	valid-many_logloss:0.44045
# [108]	train-many_logloss:0.05331	test-many_logloss:0.08840	valid-many_logloss:0.08889
# {'alpha': 0, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.8025654416649992, 'colsample_bytree': 0.8748052006921443, 'eta': 0.009393489875683971, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0, 'lambda': 0, 'max_depth': 2, 'min_child_weight': 0.013234942416650719, 'objective': 'manybinary:logistic', 'subsample': 0.8694541664166509, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.68612	test-many_logloss:0.68616	valid-many_logloss:0.68616
# [200]	train-many_logloss:0.21518	test-many_logloss:0.22003	valid-many_logloss:0.22189
# [400]	train-many_logloss:0.13603	test-many_logloss:0.14586	valid-many_logloss:0.14778
# [499]	train-many_logloss:0.11738	test-many_logloss:0.12950	valid-many_logloss:0.13154
# {'alpha': 3.1952805148613077, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.8947364949908566, 'colsample_bytree': 0.6489201195603208, 'eta': 0.04857283281713467, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0, 'lambda': 5.599926914440914e-07, 'max_depth': 4, 'min_child_weight': 1.7794291782520545e-07, 'objective': 'manybinary:logistic', 'subsample': 0.5893278373512121, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.65547	test-many_logloss:0.65585	valid-many_logloss:0.65615
# [200]	train-many_logloss:0.03912	test-many_logloss:0.07298	valid-many_logloss:0.07270
# [400]	train-many_logloss:0.02356	test-many_logloss:0.06506	valid-many_logloss:0.06420
# [499]	train-many_logloss:0.02098	test-many_logloss:0.06416	valid-many_logloss:0.06324
# NEW BEST VALUE!
# {'alpha': 3.002743880356697, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.880750740505001, 'colsample_bytree': 0.6378931895802679, 'eta': 0.07394609656696631, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0, 'lambda': 2.007018003013685e-07, 'max_depth': 4, 'min_child_weight': 0.00020723760317545867, 'objective': 'manybinary:logistic', 'subsample': 0.7957161829611085, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.63636	test-many_logloss:0.63710	valid-many_logloss:0.63734
# [200]	train-many_logloss:0.02347	test-many_logloss:0.06542	valid-many_logloss:0.06495
# [400]	train-many_logloss:0.01688	test-many_logloss:0.06290	valid-many_logloss:0.06219
# [424]	train-many_logloss:0.01660	test-many_logloss:0.06285	valid-many_logloss:0.06219
# NEW BEST VALUE!
# {'alpha': 5.61058237236068, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.8908971731457233, 'colsample_bytree': 0.6510430367754738, 'eta': 0.1335707413466269, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0, 'lambda': 1.9057159256110024e-07, 'max_depth': 4, 'min_child_weight': 0.0007171446891163338, 'objective': 'manybinary:logistic', 'subsample': 0.7985877624194806, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.59460	test-many_logloss:0.59630	valid-many_logloss:0.59663
# [200]	train-many_logloss:0.03177	test-many_logloss:0.07001	valid-many_logloss:0.07025
# [310]	train-many_logloss:0.02981	test-many_logloss:0.06924	valid-many_logloss:0.06958
# {'alpha': 5.8237356242489255, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.9108165524165766, 'colsample_bytree': 0.6246141792004032, 'eta': 0.12131776592310285, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0, 'lambda': 1.6619502097739739e-07, 'max_depth': 4, 'min_child_weight': 0.5840413635382012, 'objective': 'manybinary:logistic', 'subsample': 0.799084383736381, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.60407	test-many_logloss:0.60521	valid-many_logloss:0.60570
# [200]	train-many_logloss:0.03401	test-many_logloss:0.07133	valid-many_logloss:0.07112
# [400]	train-many_logloss:0.03062	test-many_logloss:0.06985	valid-many_logloss:0.06965
# [424]	train-many_logloss:0.03038	test-many_logloss:0.06977	valid-many_logloss:0.06962
# {'alpha': 0.3239145589491261, 'beta_eta': 0, 'btype': 'I', 'colsample_bylevel': 0.853466896885795, 'colsample_bytree': 0.6729131894243489, 'eta': 0.061858747067530695, 'eval_metric': ('many_logloss',), 'extra_dims': 0, 'gamma': 0, 'lambda': 2.3332439687544165e-05, 'max_depth': 4, 'min_child_weight': 1.6003460668400432e-06, 'objective': 'manybinary:logistic', 'subsample': 0.5885245111295248, 'output_dim': 10, 'nthread': 2}
# [0]	train-many_logloss:0.64389	test-many_logloss:0.64491	valid-many_logloss:0.64495
# [200]	train-many_logloss:0.01056	test-many_logloss:0.06041	valid-many_logloss:0.06005
# [294]	train-many_logloss:0.00495	test-many_logloss:0.05850	valid-many_logloss:0.05820
# NEW BEST VALUE!
# 100%|██████████| 25/25 [19:58<00:00, 47.96s/trial, best loss: 0.05813]

# %%
import pandas as pd
pd.DataFrame(results)
# Out:
#     iter  valid_logloss  test_logloss  num_rounds    time_diff  \
# 0      0       0.060741      0.061365         500  1184.938146
# 1      1       0.062533      0.054095         110  1097.437254
# 2      2       0.057733      0.056778         233  1135.469312
# 3      3       0.060273      0.058737         106  1092.539088
# 4      4       0.057297      0.050025         216  1126.722315
# 5      5       0.061852      0.056350         119  1109.750677
# 6      6       0.057963      0.053345         157  1137.014389
# 7      7       0.061134      0.060308         125  1100.057296
# 8      8       0.056773      0.053620         141  1208.929127
# 9      9       0.059144      0.059980         208  1104.502578
# 10    10       0.064074      0.063187         117  1117.083224
# 11    11       0.066373      0.055109         127  1111.354439
# 12    12       0.056287      0.062210         200  1127.228003
# 13    13       0.064837      0.066339         120  1113.172407
# 14    14       0.059718      0.057830         261  1114.729774
# 15    15       0.055867      0.058851         228  1127.616430
# 16    16       0.058299      0.052479         191  1094.758774
# 17    17       0.060172      0.060430         119  1154.391724
# 18    18       0.058239      0.058025         173  1109.778795
# 19    19       0.065055      0.068191         171  1125.493081
# 20    20       0.058013      0.060536         120  1110.159673
# 21    21       0.054598      0.055583         227  1106.541710
# 22    22       0.063632      0.050719         205  1108.943117
# 23    23       0.055856      0.052024         250  1133.229371
# 24    24       0.064744      0.059187         113  1063.726292
# 25    25       0.065233      0.057766         126  1107.146477
# 26    26       0.056673      0.061599         127  1100.861956
# 27    27       0.061068      0.060344         148  1142.245178
# 28    28       0.060330      0.063140         141  1137.102294
# 29    29       0.058130      0.058464         276  1198.970087
#
#                                         winning_param
# 0   {'alpha': 0, 'beta_eta': 0, 'btype': 'I', 'col...
# 1   {'alpha': 0.1617477004218055, 'beta_eta': 0, '...
# 2   {'alpha': 0.23062196782499855, 'beta_eta': 0, ...
# 3   {'alpha': 1.200782835459218, 'beta_eta': 0, 'b...
# 4   {'alpha': 0.7524380514093831, 'beta_eta': 0, '...
# 5   {'alpha': 0.19028592334432648, 'beta_eta': 0, ...
# 6   {'alpha': 0.19028592334432648, 'beta_eta': 0, ...
# 7   {'alpha': 1.200782835459218, 'beta_eta': 0, 'b...
# 8   {'alpha': 0.19028592334432648, 'beta_eta': 0, ...
# 9   {'alpha': 0.7524380514093831, 'beta_eta': 0, '...
# 10  {'alpha': 1.200782835459218, 'beta_eta': 0, 'b...
# 11  {'alpha': 0.19028592334432648, 'beta_eta': 0, ...
# 12  {'alpha': 0.7524380514093831, 'beta_eta': 0, '...
# 13  {'alpha': 0.19028592334432648, 'beta_eta': 0, ...
# 14  {'alpha': 0.23062196782499855, 'beta_eta': 0, ...
# 15  {'alpha': 0.23062196782499855, 'beta_eta': 0, ...
# 16  {'alpha': 0.7524380514093831, 'beta_eta': 0, '...
# 17  {'alpha': 1.200782835459218, 'beta_eta': 0, 'b...
# 18  {'alpha': 1.200782835459218, 'beta_eta': 0, 'b...
# 19  {'alpha': 0.7524380514093831, 'beta_eta': 0, '...
# 20  {'alpha': 1.200782835459218, 'beta_eta': 0, 'b...
# 21  {'alpha': 0.7524380514093831, 'beta_eta': 0, '...
# 22  {'alpha': 0.23062196782499855, 'beta_eta': 0, ...
# 23  {'alpha': 0.7524380514093831, 'beta_eta': 0, '...
# 24  {'alpha': 0.1617477004218055, 'beta_eta': 0, '...
# 25  {'alpha': 0.19028592334432648, 'beta_eta': 0, ...
# 26  {'alpha': 0.1617477004218055, 'beta_eta': 0, '...
# 27  {'alpha': 1.200782835459218, 'beta_eta': 0, 'b...
# 28  {'alpha': 0.19028592334432648, 'beta_eta': 0, ...
# 29  {'alpha': 0.3239145589491261, 'beta_eta': 0, '...
